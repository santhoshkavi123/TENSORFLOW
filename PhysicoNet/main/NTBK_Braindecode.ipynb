# %% [markdown]
# # Checking out Braindecode

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from braindecode.datasets import MOABBDataset
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 5
#       2 import numpy as np
#       3 import matplotlib.pyplot as plt
# ----> 5 from braindecode.datasets import MOABBDataset
#
# ModuleNotFoundError: No module named 'braindecode'

# %%
subject_id = 3
dataset = MOABBDataset(dataset_name="BNCI2014_001", subject_ids=[subject_id])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 2
#       1 subject_id = 3
# ----> 2 dataset = MOABBDataset(dataset_name="BNCI2014_001", subject_ids=[subject_id])
#
# File ~/Library/CloudStorage/OneDrive-IllinoisInstituteofTechnology/Tensorflow/PhysicoNet/.venv/lib/python3.12/site-packages/braindecode/datasets/moabb.py:152, in MOABBDataset.__init__(self, dataset_name, subject_ids, dataset_kwargs, dataset_load_kwargs)
#     144 def __init__(
#     145     self,
#     146     dataset_name: str,
#    (...)    150 ):
#     151     # soft dependency on moabb
# --> 152     from moabb import __version__ as moabb_version  # type: ignore
#     154     if moabb_version == "1.0.0":
#     155         warnings.warn(
#     156             "moabb version 1.0.0 generates incorrect annotations. "
#     157             "Please update to another version, version 0.5 or 1.1.0 "
# ...
