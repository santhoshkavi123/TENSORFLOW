# %% [markdown]
# # Import Required Libraries

# %%
import os
import re
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# sklearn packages
from sklearn.preprocessing import (StandardScaler, 
                                    MinMaxScaler)

from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC

from sklearn.pipeline import make_pipeline
from sklearn.model_selection import StratifiedShuffleSplit, RandomizedSearchCV, train_test_split

from sklearn.metrics import (accuracy_score, 
                            classification_report, 
                            confusion_matrix, 
                            ConfusionMatrixDisplay)


# MNE Packages
import mne
from mne.datasets.sleep_physionet.age import fetch_data
mne.utils.set_config('MNE_USE_CUDA', 'true')



import torch
import torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader, random_split
import torch.optim as optim
import torch.nn.functional as F
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

from braindecode.models import EEGNetv1
from braindecode import EEGClassifier
from skorch.callbacks import LRScheduler

# %%
class EEGEpochExtractor:
    def __init__(self, data_dir):
        """
        Initialize the extractor with the directory containing EDF files.
        """
        self.data_dir = data_dir
        self.all_epochs = []

    # --- Trail classification ---
    @staticmethod
    def trail_classification(trail_num: int) -> str:
        if trail_num in [4, 6, 8, 10, 12, 14]:
            return "imaginary"
        elif trail_num in [1, 2]:
            return "baseline"
        else:
            return "motor"

    # --- Event type classification ---
    @staticmethod
    def event_type_classification(trail_num: int):
        if trail_num in [1, 2]:
            return ("rest", "NA", "NA")
        elif trail_num in [3, 4, 7, 8, 11, 12]:
            return ("rest", "left_fist", "right_fist")
        elif trail_num in [5, 6, 9, 10, 13, 14]:
            return ("rest", "both_fist", "both_feet")

    # --- Metadata extraction ---
    def extract_metadata(self) -> pd.DataFrame:
        metadata = []

        for subj in sorted(os.listdir(self.data_dir)):
            subj_path = os.path.join(self.data_dir, subj)
            if not os.path.isdir(subj_path):
                continue

            for file in sorted(os.listdir(subj_path)):
                if file.endswith(".edf") and not file.endswith(".edf.event"):
                    match = re.search(r"R(\d{2})\.edf$", file)
                    if match:
                        trial_num = int(match.group(1))
                        trail_type = self.trail_classification(trial_num)
                        event_type = self.event_type_classification(trial_num)

                        edf_file = os.path.join(subj_path, file)
                        event_file = edf_file + ".event" if os.path.exists(edf_file + ".event") else None

                        metadata.append({
                            "subject": subj,
                            "trial": trial_num,
                            "trail_type": trail_type,
                            "edf_file": edf_file,
                            "event_file": event_file,
                            "T0": event_type[0],
                            "T1": event_type[1],
                            "T2": event_type[2],
                        })

        self.metadata_df = pd.DataFrame(metadata)
        return self.metadata_df


    def process_file(self, file_path, event_id_mapping):
        """
        Process a single EDF file and return epochs.
        """
        print(f"Processing: {file_path}")
        raw_edf = mne.io.read_raw_edf(file_path, preload=True)
        annotations_edf = mne.read_annotations(file_path)

        # Update annotation descriptions
        new_descriptions = [
            event_id_mapping.get(desc, desc) for desc in annotations_edf.description
        ]
        annotations_edf.description = new_descriptions
        
        # Set updated annotations
        raw_edf.set_annotations(annotations_edf)
        
        # Convert annotations to events
        events, event_id = mne.events_from_annotations(raw_edf)
        
        
        epochs = mne.Epochs(
            raw=raw_edf,
            events=events,
            event_id= event_id,
            reject = None,
            flat = None, 
            reject_by_annotation= False, 
            baseline=None,
            preload=True
        )
        return epochs

    def process_all(self):
        """
        Process all EDF files in the directory and store their epochs.
        """
        metadata_info = self.extract_metadata() # Metadata Information
        self.all_epochs = []  # reset list
        for filename in metadata_info["edf_file"].tolist():
            if filename.endswith(".edf"):
                event_id_mapping = {"T0": metadata_info[(metadata_info["edf_file"]==filename)]["T0"].values[0], 
                                    "T1": metadata_info[(metadata_info["edf_file"]==filename)]["T1"].values[0], 
                                    "T2": metadata_info[(metadata_info["edf_file"]==filename)]["T2"].values[0]}
                print(event_id_mapping)
                epochs = self.process_file(file_path=filename, event_id_mapping= event_id_mapping)
                self.all_epochs.append(epochs)
        
        print(f"\nTotal EDF files processed: {len(self.all_epochs)}")
        return self.all_epochs

# %%
extractor = EEGEpochExtractor(data_dir= "../data/Original/")
all_epochs = extractor.process_all()
# Out:
# {'T0': 'rest', 'T1': 'NA', 'T2': 'NA'}
# Processing: ../data/Original/S001/S001R01.edf
# Extracting EDF parameters from /Users/kavisanthoshkumar/Library/CloudStorage/OneDrive-IllinoisInstituteofTechnology/Tensorflow/PhysicoNet/data/Original/S001/S001R01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# Used Annotations descriptions: [np.str_('rest')]
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 113 original time points ...
# 1 bad epochs dropped
# {'T0': 'rest', 'T1': 'NA', 'T2': 'NA'}
# Processing: ../data/Original/S001/S001R02.edf
# Extracting EDF parameters from /Users/kavisanthoshkumar/Library/CloudStorage/OneDrive-IllinoisInstituteofTechnology/Tensorflow/PhysicoNet/data/Original/S001/S001R02.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# Used Annotations descriptions: [np.str_('rest')]
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 113 original time points ...
# 1 bad epochs dropped
# {'T0': 'rest', 'T1': 'left_fist', 'T2': 'right_fist'}
# Processing: ../data/Original/S001/S001R03.edf
# Extracting EDF parameters from /Users/kavisanthoshkumar/Library/CloudStorage/OneDrive-IllinoisInstituteofTechnology/Tensorflow/PhysicoNet/data/Original/S001/S001R03.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19999  =      0.000 ...   124.994 secs...
# Used Annotations descriptions: [np.str_('left_fist'), np.str_('rest'), np.str_('right_fist')]
# Not setting metadata
# 30 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 30 events and 113 original time points ...
# 1 bad epochs dropped
# {'T0': 'rest', 'T1': 'left_fist', 'T2': 'right_fist'}
# Processing: ../data/Original/S001/S001R04.edf
# Extracting EDF parameters from /Users/kavisanthoshkumar/Library/CloudStorage/OneDrive-IllinoisInstituteofTechnology/Tensorflow/PhysicoNet/data/Original/S001/S001R04.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19999  =      0.000 ...   124.994 secs...
# Used Annotations descriptions: [np.str_('left_fist'), np.str_('rest'), np.str_('right_fist')]
# Not setting metadata
# 30 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 30 events and 113 original time points ...
# 1 bad epochs dropped
# {'T0': 'rest', 'T1': 'both_fist', 'T2': 'both_feet'}
# Processing: ../data/Original/S001/S001R05.edf
# Extracting EDF parameters from /Users/kavisanthoshkumar/Library/CloudStorage/OneDrive-IllinoisInstituteofTechnology/Tensorflow/PhysicoNet/data/Original/S001/S001R05.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19999  =      0.000 ...   124.994 secs...
# Used Annotations descriptions: [np.str_('both_feet'), np.str_('both_fist'), np.str_('rest')]
# Not setting metadata
# 30 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 30 events and 113 original time points ...
# 1 bad epochs dropped
# {'T0': 'rest', 'T1': 'both_fist', 'T2': 'both_feet'}
# Processing: ../data/Original/S001/S001R06.edf
# Extracting EDF parameters from /Users/kavisanthoshkumar/Library/CloudStorage/OneDrive-IllinoisInstituteofTechnology/Tensorflow/PhysicoNet/data/Original/S001/S001R06.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19999  =      0.000 ...   124.994 secs...
# Used Annotations descriptions: [np.str_('both_feet'), np.str_('both_fist'), np.str_('rest')]
# Not setting metadata
# 30 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 30 events and 113 original time points ...
# 1 bad epochs dropped
# {'T0': 'rest', 'T1': 'left_fist', 'T2': 'right_fist'}
# Processing: ../data/Original/S001/S001R07.edf
# Extracting EDF parameters from /Users/kavisanthoshkumar/Library/CloudStorage/OneDrive-IllinoisInstituteofTechnology/Tensorflow/PhysicoNet/data/Original/S001/S001R07.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19999  =      0.000 ...   124.994 secs...
# Used Annotations descriptions: [np.str_('left_fist'), np.str_('rest'), np.str_('right_fist')]
# Not setting metadata
# 30 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 30 events and 113 original time points ...
# 1 bad epochs dropped
# {'T0': 'rest', 'T1': 'left_fist', 'T2': 'right_fist'}
# Processing: ../data/Original/S001/S001R08.edf
# Extracting EDF parameters from /Users/kavisanthoshkumar/Library/CloudStorage/OneDrive-IllinoisInstituteofTechnology/Tensorflow/PhysicoNet/data/Original/S001/S001R08.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# /var/folders/_p/pgtp_zhj7n3717r3m0prtkdh0000gn/T/ipykernel_16071/3325446389.py:85: RuntimeWarning: All epochs were dropped!
# You might need to alter reject/flat-criteria or drop bad channels to avoid this. You can use Epochs.plot_drop_log() to see which channels are responsible for the dropping of epochs.
#   epochs = mne.Epochs(
# /var/folders/_p/pgtp_zhj7n3717r3m0prtkdh0000gn/T/ipykernel_16071/3325446389.py:85: RuntimeWarning: All epochs were dropped!
# You might need to alter reject/flat-criteria or drop bad channels to avoid this. You can use Epochs.plot_drop_log() to see which channels are responsible for the dropping of epochs.
#   epochs = mne.Epochs(
# Reading 0 ... 19999  =      0.000 ...   124.994 secs...
# Used Annotations descriptions: [np.str_('left_fist'), np.str_('rest'), np.str_('right_fist')]
# Not setting metadata
# 30 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 30 events and 113 original time points ...
# 1 bad epochs dropped
# {'T0': 'rest', 'T1': 'both_fist', 'T2': 'both_feet'}
# Processing: ../data/Original/S001/S001R09.edf
# Extracting EDF parameters from /Users/kavisanthoshkumar/Library/CloudStorage/OneDrive-IllinoisInstituteofTechnology/Tensorflow/PhysicoNet/data/Original/S001/S001R09.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19999  =      0.000 ...   124.994 secs...
# Used Annotations descriptions: [np.str_('both_feet'), np.str_('both_fist'), np.str_('rest')]
# Not setting metadata
# 30 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 30 events and 113 original time points ...
# 1 bad epochs dropped
# {'T0': 'rest', 'T1': 'both_fist', 'T2': 'both_feet'}
# Processing: ../data/Original/S001/S001R10.edf
# Extracting EDF parameters from /Users/kavisanthoshkumar/Library/CloudStorage/OneDrive-IllinoisInstituteofTechnology/Tensorflow/PhysicoNet/data/Original/S001/S001R10.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19999  =      0.000 ...   124.994 secs...
# Used Annotations descriptions: [np.str_('both_feet'), np.str_('both_fist'), np.str_('rest')]
# Not setting metadata
# 30 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 30 events and 113 original time points ...
# 1 bad epochs dropped
# {'T0': 'rest', 'T1': 'left_fist', 'T2': 'right_fist'}
# Processing: ../data/Original/S001/S001R11.edf
# Extracting EDF parameters from /Users/kavisanthoshkumar/Library/CloudStorage/OneDrive-IllinoisInstituteofTechnology/Tensorflow/PhysicoNet/data/Original/S001/S001R11.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19999  =      0.000 ...   124.994 secs...
# Used Annotations descriptions: [np.str_('left_fist'), np.str_('rest'), np.str_('right_fist')]
# Not setting metadata
# 30 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 30 events and 113 original time points ...
# 1 bad epochs dropped
# {'T0': 'rest', 'T1': 'left_fist', 'T2': 'right_fist'}
# Processing: ../data/Original/S001/S001R12.edf
# Extracting EDF parameters from /Users/kavisanthoshkumar/Library/CloudStorage/OneDrive-IllinoisInstituteofTechnology/Tensorflow/PhysicoNet/data/Original/S001/S001R12.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19999  =      0.000 ...   124.994 secs...
# Used Annotations descriptions: [np.str_('left_fist'), np.str_('rest'), np.str_('right_fist')]
# Not setting metadata
# 30 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 30 events and 113 original time points ...
# 1 bad epochs dropped
# {'T0': 'rest', 'T1': 'both_fist', 'T2': 'both_feet'}
# Processing: ../data/Original/S001/S001R13.edf
# Extracting EDF parameters from /Users/kavisanthoshkumar/Library/CloudStorage/OneDrive-IllinoisInstituteofTechnology/Tensorflow/PhysicoNet/data/Original/S001/S001R13.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19999  =      0.000 ...   124.994 secs...
# Used Annotations descriptions: [np.str_('both_feet'), np.str_('both_fist'), np.str_('rest')]
# Not setting metadata
# 30 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 30 events and 113 original time points ...
# 1 bad epochs dropped
# {'T0': 'rest', 'T1': 'both_fist', 'T2': 'both_feet'}
# Processing: ../data/Original/S001/S001R14.edf
# Extracting EDF parameters from /Users/kavisanthoshkumar/Library/CloudStorage/OneDrive-IllinoisInstituteofTechnology/Tensorflow/PhysicoNet/data/Original/S001/S001R14.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19999  =      0.000 ...   124.994 secs...
# Used Annotations descriptions: [np.str_('both_feet'), np.str_('both_fist'), np.str_('rest')]
# Not setting metadata
# 30 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 30 events and 113 original time points ...
# 1 bad epochs dropped
# {'T0': 'rest', 'T1': 'NA', 'T2': 'NA'}
# Processing: ../data/Original/S002/S002R01.edf
# Extracting EDF parameters from /Users/kavisanthoshkumar/Library/CloudStorage/OneDrive-IllinoisInstituteofTechnology/Tensorflow/PhysicoNet/data/Original/S002/S002R01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# Used Annotations descriptions: [np.str_('rest')]
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 113 original time points ...
# 1 bad epochs dropped
# {'T0': 'rest', 'T1': 'NA', 'T2': 'NA'}
# Processing: ../data/Original/S002/S002R02.edf
# Extracting EDF parameters from /Users/kavisanthoshkumar/Library/CloudStorage/OneDrive-IllinoisInstituteofTechnology/Tensorflow/PhysicoNet/data/Original/S002/S002R02.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# Used Annotations descriptions: [np.str_('rest')]
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 113 original time points ...
# 1 bad epochs dropped
# {'T0': 'rest', 'T1': 'left_fist', 'T2': 'right_fist'}
# Processing: ../data/Original/S002/S002R03.edf
# Extracting EDF parameters from /Users/kavisanthoshkumar/Library/CloudStorage/OneDrive-IllinoisInstituteofTechnology/Tensorflow/PhysicoNet/data/Original/S002/S002R03.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: [np.str_('left_fist'), np.str_('rest'), np.str_('right_fist')]
# Not setting metadata
# 30 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 30 events and 113 original time points ...
# 1 bad epochs dropped
# {'T0': 'rest', 'T1': 'left_fist', 'T2': 'right_fist'}
# Processing: ../data/Original/S002/S002R04.edf
# Extracting EDF parameters from /Users/kavisanthoshkumar/Library/CloudStorage/OneDrive-IllinoisInstituteofTechnology/Tensorflow/PhysicoNet/data/Original/S002/S002R04.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: [np.str_('left_fist'), np.str_('rest'), np.str_('right_fist')]
# Not setting metadata
# 30 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 30 events and 113 original time points ...
# 1 bad epochs dropped
# {'T0': 'rest', 'T1': 'both_fist', 'T2': 'both_feet'}
# Processing: ../data/Original/S002/S002R05.edf
# Extracting EDF parameters from /Users/kavisanthoshkumar/Library/CloudStorage/OneDrive-IllinoisInstituteofTechnology/Tensorflow/PhysicoNet/data/Original/S002/S002R05.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: [np.str_('both_feet'), np.str_('both_fist'), np.str_('rest')]
# Not setting metadata
# 30 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 30 events and 113 original time points ...
# 1 bad epochs dropped
# {'T0': 'rest', 'T1': 'both_fist', 'T2': 'both_feet'}
# Processing: ../data/Original/S002/S002R06.edf
# Extracting EDF parameters from /Users/kavisanthoshkumar/Library/CloudStorage/OneDrive-IllinoisInstituteofTechnology/Tensorflow/PhysicoNet/data/Original/S002/S002R06.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: [np.str_('both_feet'), np.str_('both_fist'), np.str_('rest')]
# Not setting metadata
# 30 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 30 events and 113 original time points ...
# 1 bad epochs dropped
# {'T0': 'rest', 'T1': 'left_fist', 'T2': 'right_fist'}
# Processing: ../data/Original/S002/S002R07.edf
# Extracting EDF parameters from /Users/kavisanthoshkumar/Library/CloudStorage/OneDrive-IllinoisInstituteofTechnology/Tensorflow/PhysicoNet/data/Original/S002/S002R07.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: [np.str_('left_fist'), np.str_('rest'), np.str_('right_fist')]
# Not setting metadata
# 30 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 30 events and 113 original time points ...
# 1 bad epochs dropped
# {'T0': 'rest', 'T1': 'left_fist', 'T2': 'right_fist'}
# Processing: ../data/Original/S002/S002R08.edf
# Extracting EDF parameters from /Users/kavisanthoshkumar/Library/CloudStorage/OneDrive-IllinoisInstituteofTechnology/Tensorflow/PhysicoNet/data/Original/S002/S002R08.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: [np.str_('left_fist'), np.str_('rest'), np.str_('right_fist')]
# Not setting metadata
# 30 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 30 events and 113 original time points ...
# /var/folders/_p/pgtp_zhj7n3717r3m0prtkdh0000gn/T/ipykernel_16071/3325446389.py:85: RuntimeWarning: All epochs were dropped!
# You might need to alter reject/flat-criteria or drop bad channels to avoid this. You can use Epochs.plot_drop_log() to see which channels are responsible for the dropping of epochs.
#   epochs = mne.Epochs(
# /var/folders/_p/pgtp_zhj7n3717r3m0prtkdh0000gn/T/ipykernel_16071/3325446389.py:85: RuntimeWarning: All epochs were dropped!
# You might need to alter reject/flat-criteria or drop bad channels to avoid this. You can use Epochs.plot_drop_log() to see which channels are responsible for the dropping of epochs.
#   epochs = mne.Epochs(
# 1 bad epochs dropped
# {'T0': 'rest', 'T1': 'both_fist', 'T2': 'both_feet'}
# Processing: ../data/Original/S002/S002R09.edf
# Extracting EDF parameters from /Users/kavisanthoshkumar/Library/CloudStorage/OneDrive-IllinoisInstituteofTechnology/Tensorflow/PhysicoNet/data/Original/S002/S002R09.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: [np.str_('both_feet'), np.str_('both_fist'), np.str_('rest')]
# Not setting metadata
# 30 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 30 events and 113 original time points ...
# 1 bad epochs dropped
# {'T0': 'rest', 'T1': 'both_fist', 'T2': 'both_feet'}
# Processing: ../data/Original/S002/S002R10.edf
# Extracting EDF parameters from /Users/kavisanthoshkumar/Library/CloudStorage/OneDrive-IllinoisInstituteofTechnology/Tensorflow/PhysicoNet/data/Original/S002/S002R10.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: [np.str_('both_feet'), np.str_('both_fist'), np.str_('rest')]
# Not setting metadata
# 30 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 30 events and 113 original time points ...
# 1 bad epochs dropped
# {'T0': 'rest', 'T1': 'left_fist', 'T2': 'right_fist'}
# Processing: ../data/Original/S002/S002R11.edf
# Extracting EDF parameters from /Users/kavisanthoshkumar/Library/CloudStorage/OneDrive-IllinoisInstituteofTechnology/Tensorflow/PhysicoNet/data/Original/S002/S002R11.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: [np.str_('left_fist'), np.str_('rest'), np.str_('right_fist')]
# Not setting metadata
# 30 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 30 events and 113 original time points ...
# 1 bad epochs dropped
# {'T0': 'rest', 'T1': 'left_fist', 'T2': 'right_fist'}
# Processing: ../data/Original/S002/S002R12.edf
# Extracting EDF parameters from /Users/kavisanthoshkumar/Library/CloudStorage/OneDrive-IllinoisInstituteofTechnology/Tensorflow/PhysicoNet/data/Original/S002/S002R12.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: [np.str_('left_fist'), np.str_('rest'), np.str_('right_fist')]
# Not setting metadata
# 30 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 30 events and 113 original time points ...
# 1 bad epochs dropped
# {'T0': 'rest', 'T1': 'both_fist', 'T2': 'both_feet'}
# Processing: ../data/Original/S002/S002R13.edf
# Extracting EDF parameters from /Users/kavisanthoshkumar/Library/CloudStorage/OneDrive-IllinoisInstituteofTechnology/Tensorflow/PhysicoNet/data/Original/S002/S002R13.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: [np.str_('both_feet'), np.str_('both_fist'), np.str_('rest')]
# Not setting metadata
# 30 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 30 events and 113 original time points ...
# 1 bad epochs dropped
# {'T0': 'rest', 'T1': 'both_fist', 'T2': 'both_feet'}
# Processing: ../data/Original/S002/S002R14.edf
# Extracting EDF parameters from /Users/kavisanthoshkumar/Library/CloudStorage/OneDrive-IllinoisInstituteofTechnology/Tensorflow/PhysicoNet/data/Original/S002/S002R14.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: [np.str_('both_feet'), np.str_('both_fist'), np.str_('rest')]
# Not setting metadata
# 30 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 30 events and 113 original time points ...
# 1 bad epochs dropped
# {'T0': 'rest', 'T1': 'NA', 'T2': 'NA'}
# Processing: ../data/Original/S003/S003R01.edf
# Extracting EDF parameters from /Users/kavisanthoshkumar/Library/CloudStorage/OneDrive-IllinoisInstituteofTechnology/Tensorflow/PhysicoNet/data/Original/S003/S003R01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# Used Annotations descriptions: [np.str_('rest')]
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 113 original time points ...
# 1 bad epochs dropped
# {'T0': 'rest', 'T1': 'NA', 'T2': 'NA'}
# Processing: ../data/Original/S003/S003R02.edf
# Extracting EDF parameters from /Users/kavisanthoshkumar/Library/CloudStorage/OneDrive-IllinoisInstituteofTechnology/Tensorflow/PhysicoNet/data/Original/S003/S003R02.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# Used Annotations descriptions: [np.str_('rest')]
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 113 original time points ...
# 1 bad epochs dropped
# {'T0': 'rest', 'T1': 'left_fist', 'T2': 'right_fist'}
# Processing: ../data/Original/S003/S003R03.edf
# Extracting EDF parameters from /Users/kavisanthoshkumar/Library/CloudStorage/OneDrive-IllinoisInstituteofTechnology/Tensorflow/PhysicoNet/data/Original/S003/S003R03.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19999  =      0.000 ...   124.994 secs...
# Used Annotations descriptions: [np.str_('left_fist'), np.str_('rest'), np.str_('right_fist')]
# Not setting metadata
# 30 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 30 events and 113 original time points ...
# 1 bad epochs dropped
# {'T0': 'rest', 'T1': 'left_fist', 'T2': 'right_fist'}
# Processing: ../data/Original/S003/S003R04.edf
# Extracting EDF parameters from /Users/kavisanthoshkumar/Library/CloudStorage/OneDrive-IllinoisInstituteofTechnology/Tensorflow/PhysicoNet/data/Original/S003/S003R04.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19999  =      0.000 ...   124.994 secs...
# Used Annotations descriptions: [np.str_('left_fist'), np.str_('rest'), np.str_('right_fist')]
# Not setting metadata
# 30 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 30 events and 113 original time points ...
# 1 bad epochs dropped
# {'T0': 'rest', 'T1': 'both_fist', 'T2': 'both_feet'}
# Processing: ../data/Original/S003/S003R05.edf
# Extracting EDF parameters from /Users/kavisanthoshkumar/Library/CloudStorage/OneDrive-IllinoisInstituteofTechnology/Tensorflow/PhysicoNet/data/Original/S003/S003R05.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19999  =      0.000 ...   124.994 secs...
# Used Annotations descriptions: [np.str_('both_feet'), np.str_('both_fist'), np.str_('rest')]
# Not setting metadata
# 30 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 30 events and 113 original time points ...
# 1 bad epochs dropped
# {'T0': 'rest', 'T1': 'both_fist', 'T2': 'both_feet'}
# Processing: ../data/Original/S003/S003R06.edf
# Extracting EDF parameters from /Users/kavisanthoshkumar/Library/CloudStorage/OneDrive-IllinoisInstituteofTechnology/Tensorflow/PhysicoNet/data/Original/S003/S003R06.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19999  =      0.000 ...   124.994 secs...
# Used Annotations descriptions: [np.str_('both_feet'), np.str_('both_fist'), np.str_('rest')]
# Not setting metadata
# 30 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 30 events and 113 original time points ...
# 1 bad epochs dropped
# {'T0': 'rest', 'T1': 'left_fist', 'T2': 'right_fist'}
# Processing: ../data/Original/S003/S003R07.edf
# Extracting EDF parameters from /Users/kavisanthoshkumar/Library/CloudStorage/OneDrive-IllinoisInstituteofTechnology/Tensorflow/PhysicoNet/data/Original/S003/S003R07.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19999  =      0.000 ...   124.994 secs...
# Used Annotations descriptions: [np.str_('left_fist'), np.str_('rest'), np.str_('right_fist')]
# Not setting metadata
# 30 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 30 events and 113 original time points ...
# 1 bad epochs dropped
# {'T0': 'rest', 'T1': 'left_fist', 'T2': 'right_fist'}
# Processing: ../data/Original/S003/S003R08.edf
# Extracting EDF parameters from /Users/kavisanthoshkumar/Library/CloudStorage/OneDrive-IllinoisInstituteofTechnology/Tensorflow/PhysicoNet/data/Original/S003/S003R08.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19999  =      0.000 ...   124.994 secs...
# /var/folders/_p/pgtp_zhj7n3717r3m0prtkdh0000gn/T/ipykernel_16071/3325446389.py:85: RuntimeWarning: All epochs were dropped!
# You might need to alter reject/flat-criteria or drop bad channels to avoid this. You can use Epochs.plot_drop_log() to see which channels are responsible for the dropping of epochs.
#   epochs = mne.Epochs(
# /var/folders/_p/pgtp_zhj7n3717r3m0prtkdh0000gn/T/ipykernel_16071/3325446389.py:85: RuntimeWarning: All epochs were dropped!
# You might need to alter reject/flat-criteria or drop bad channels to avoid this. You can use Epochs.plot_drop_log() to see which channels are responsible for the dropping of epochs.
#   epochs = mne.Epochs(
# Used Annotations descriptions: [np.str_('left_fist'), np.str_('rest'), np.str_('right_fist')]
# Not setting metadata
# 30 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 30 events and 113 original time points ...
# 1 bad epochs dropped
# {'T0': 'rest', 'T1': 'both_fist', 'T2': 'both_feet'}
# Processing: ../data/Original/S003/S003R09.edf
# Extracting EDF parameters from /Users/kavisanthoshkumar/Library/CloudStorage/OneDrive-IllinoisInstituteofTechnology/Tensorflow/PhysicoNet/data/Original/S003/S003R09.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19999  =      0.000 ...   124.994 secs...
# Used Annotations descriptions: [np.str_('both_feet'), np.str_('both_fist'), np.str_('rest')]
# Not setting metadata
# 30 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 30 events and 113 original time points ...
# 1 bad epochs dropped
# {'T0': 'rest', 'T1': 'both_fist', 'T2': 'both_feet'}
# Processing: ../data/Original/S003/S003R10.edf
# Extracting EDF parameters from /Users/kavisanthoshkumar/Library/CloudStorage/OneDrive-IllinoisInstituteofTechnology/Tensorflow/PhysicoNet/data/Original/S003/S003R10.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19999  =      0.000 ...   124.994 secs...
# Used Annotations descriptions: [np.str_('both_feet'), np.str_('both_fist'), np.str_('rest')]
# Not setting metadata
# 30 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 30 events and 113 original time points ...
# 1 bad epochs dropped
# {'T0': 'rest', 'T1': 'left_fist', 'T2': 'right_fist'}
# Processing: ../data/Original/S003/S003R11.edf
# Extracting EDF parameters from /Users/kavisanthoshkumar/Library/CloudStorage/OneDrive-IllinoisInstituteofTechnology/Tensorflow/PhysicoNet/data/Original/S003/S003R11.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19999  =      0.000 ...   124.994 secs...
# Used Annotations descriptions: [np.str_('left_fist'), np.str_('rest'), np.str_('right_fist')]
# Not setting metadata
# 30 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 30 events and 113 original time points ...
# 1 bad epochs dropped
# {'T0': 'rest', 'T1': 'left_fist', 'T2': 'right_fist'}
# Processing: ../data/Original/S003/S003R12.edf
# Extracting EDF parameters from /Users/kavisanthoshkumar/Library/CloudStorage/OneDrive-IllinoisInstituteofTechnology/Tensorflow/PhysicoNet/data/Original/S003/S003R12.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19999  =      0.000 ...   124.994 secs...
# Used Annotations descriptions: [np.str_('left_fist'), np.str_('rest'), np.str_('right_fist')]
# Not setting metadata
# 30 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 30 events and 113 original time points ...
# 1 bad epochs dropped
# {'T0': 'rest', 'T1': 'both_fist', 'T2': 'both_feet'}
# Processing: ../data/Original/S003/S003R13.edf
# Extracting EDF parameters from /Users/kavisanthoshkumar/Library/CloudStorage/OneDrive-IllinoisInstituteofTechnology/Tensorflow/PhysicoNet/data/Original/S003/S003R13.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19999  =      0.000 ...   124.994 secs...
# Used Annotations descriptions: [np.str_('both_feet'), np.str_('both_fist'), np.str_('rest')]
# Not setting metadata
# 30 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 30 events and 113 original time points ...
# 1 bad epochs dropped
# {'T0': 'rest', 'T1': 'both_fist', 'T2': 'both_feet'}
# Processing: ../data/Original/S003/S003R14.edf
# Extracting EDF parameters from /Users/kavisanthoshkumar/Library/CloudStorage/OneDrive-IllinoisInstituteofTechnology/Tensorflow/PhysicoNet/data/Original/S003/S003R14.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19999  =      0.000 ...   124.994 secs...
# Used Annotations descriptions: [np.str_('both_feet'), np.str_('both_fist'), np.str_('rest')]
# Not setting metadata
# 30 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 30 events and 113 original time points ...
# 1 bad epochs dropped
# {'T0': 'rest', 'T1': 'NA', 'T2': 'NA'}
# Processing: ../data/Original/S004/S004R01.edf
# Extracting EDF parameters from /Users/kavisanthoshkumar/Library/CloudStorage/OneDrive-IllinoisInstituteofTechnology/Tensorflow/PhysicoNet/data/Original/S004/S004R01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# Used Annotations descriptions: [np.str_('rest')]
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 113 original time points ...
# 1 bad epochs dropped
# {'T0': 'rest', 'T1': 'NA', 'T2': 'NA'}
# Processing: ../data/Original/S004/S004R02.edf
# Extracting EDF parameters from /Users/kavisanthoshkumar/Library/CloudStorage/OneDrive-IllinoisInstituteofTechnology/Tensorflow/PhysicoNet/data/Original/S004/S004R02.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# Used Annotations descriptions: [np.str_('rest')]
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 113 original time points ...
# 1 bad epochs dropped
# {'T0': 'rest', 'T1': 'left_fist', 'T2': 'right_fist'}
# Processing: ../data/Original/S004/S004R03.edf
# Extracting EDF parameters from /Users/kavisanthoshkumar/Library/CloudStorage/OneDrive-IllinoisInstituteofTechnology/Tensorflow/PhysicoNet/data/Original/S004/S004R03.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: [np.str_('left_fist'), np.str_('rest'), np.str_('right_fist')]
# Not setting metadata
# 30 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 30 events and 113 original time points ...
# 1 bad epochs dropped
# {'T0': 'rest', 'T1': 'left_fist', 'T2': 'right_fist'}
# Processing: ../data/Original/S004/S004R04.edf
# Extracting EDF parameters from /Users/kavisanthoshkumar/Library/CloudStorage/OneDrive-IllinoisInstituteofTechnology/Tensorflow/PhysicoNet/data/Original/S004/S004R04.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: [np.str_('left_fist'), np.str_('rest'), np.str_('right_fist')]
# Not setting metadata
# 30 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 30 events and 113 original time points ...
# 1 bad epochs dropped
# {'T0': 'rest', 'T1': 'both_fist', 'T2': 'both_feet'}
# Processing: ../data/Original/S004/S004R05.edf
# Extracting EDF parameters from /Users/kavisanthoshkumar/Library/CloudStorage/OneDrive-IllinoisInstituteofTechnology/Tensorflow/PhysicoNet/data/Original/S004/S004R05.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: [np.str_('both_feet'), np.str_('both_fist'), np.str_('rest')]
# Not setting metadata
# 30 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 30 events and 113 original time points ...
# 1 bad epochs dropped
# {'T0': 'rest', 'T1': 'both_fist', 'T2': 'both_feet'}
# Processing: ../data/Original/S004/S004R06.edf
# Extracting EDF parameters from /Users/kavisanthoshkumar/Library/CloudStorage/OneDrive-IllinoisInstituteofTechnology/Tensorflow/PhysicoNet/data/Original/S004/S004R06.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: [np.str_('both_feet'), np.str_('both_fist'), np.str_('rest')]
# Not setting metadata
# 30 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 30 events and 113 original time points ...
# 1 bad epochs dropped
# {'T0': 'rest', 'T1': 'left_fist', 'T2': 'right_fist'}
# Processing: ../data/Original/S004/S004R07.edf
# Extracting EDF parameters from /Users/kavisanthoshkumar/Library/CloudStorage/OneDrive-IllinoisInstituteofTechnology/Tensorflow/PhysicoNet/data/Original/S004/S004R07.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: [np.str_('left_fist'), np.str_('rest'), np.str_('right_fist')]
# Not setting metadata
# 30 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 30 events and 113 original time points ...
# 1 bad epochs dropped
# {'T0': 'rest', 'T1': 'left_fist', 'T2': 'right_fist'}
# Processing: ../data/Original/S004/S004R08.edf
# Extracting EDF parameters from /Users/kavisanthoshkumar/Library/CloudStorage/OneDrive-IllinoisInstituteofTechnology/Tensorflow/PhysicoNet/data/Original/S004/S004R08.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# /var/folders/_p/pgtp_zhj7n3717r3m0prtkdh0000gn/T/ipykernel_16071/3325446389.py:85: RuntimeWarning: All epochs were dropped!
# You might need to alter reject/flat-criteria or drop bad channels to avoid this. You can use Epochs.plot_drop_log() to see which channels are responsible for the dropping of epochs.
#   epochs = mne.Epochs(
# /var/folders/_p/pgtp_zhj7n3717r3m0prtkdh0000gn/T/ipykernel_16071/3325446389.py:85: RuntimeWarning: All epochs were dropped!
# You might need to alter reject/flat-criteria or drop bad channels to avoid this. You can use Epochs.plot_drop_log() to see which channels are responsible for the dropping of epochs.
#   epochs = mne.Epochs(
# Used Annotations descriptions: [np.str_('left_fist'), np.str_('rest'), np.str_('right_fist')]
# Not setting metadata
# 30 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 30 events and 113 original time points ...
# 1 bad epochs dropped
# {'T0': 'rest', 'T1': 'both_fist', 'T2': 'both_feet'}
# Processing: ../data/Original/S004/S004R09.edf
# Extracting EDF parameters from /Users/kavisanthoshkumar/Library/CloudStorage/OneDrive-IllinoisInstituteofTechnology/Tensorflow/PhysicoNet/data/Original/S004/S004R09.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: [np.str_('both_feet'), np.str_('both_fist'), np.str_('rest')]
# Not setting metadata
# 30 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 30 events and 113 original time points ...
# 1 bad epochs dropped
# {'T0': 'rest', 'T1': 'both_fist', 'T2': 'both_feet'}
# Processing: ../data/Original/S004/S004R10.edf
# Extracting EDF parameters from /Users/kavisanthoshkumar/Library/CloudStorage/OneDrive-IllinoisInstituteofTechnology/Tensorflow/PhysicoNet/data/Original/S004/S004R10.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: [np.str_('both_feet'), np.str_('both_fist'), np.str_('rest')]
# Not setting metadata
# 30 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 30 events and 113 original time points ...
# 1 bad epochs dropped
# {'T0': 'rest', 'T1': 'left_fist', 'T2': 'right_fist'}
# Processing: ../data/Original/S004/S004R11.edf
# Extracting EDF parameters from /Users/kavisanthoshkumar/Library/CloudStorage/OneDrive-IllinoisInstituteofTechnology/Tensorflow/PhysicoNet/data/Original/S004/S004R11.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: [np.str_('left_fist'), np.str_('rest'), np.str_('right_fist')]
# Not setting metadata
# 30 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 30 events and 113 original time points ...
# 1 bad epochs dropped
# {'T0': 'rest', 'T1': 'left_fist', 'T2': 'right_fist'}
# Processing: ../data/Original/S004/S004R12.edf
# Extracting EDF parameters from /Users/kavisanthoshkumar/Library/CloudStorage/OneDrive-IllinoisInstituteofTechnology/Tensorflow/PhysicoNet/data/Original/S004/S004R12.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: [np.str_('left_fist'), np.str_('rest'), np.str_('right_fist')]
# Not setting metadata
# 30 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 30 events and 113 original time points ...
# 1 bad epochs dropped
# {'T0': 'rest', 'T1': 'both_fist', 'T2': 'both_feet'}
# Processing: ../data/Original/S004/S004R13.edf
# Extracting EDF parameters from /Users/kavisanthoshkumar/Library/CloudStorage/OneDrive-IllinoisInstituteofTechnology/Tensorflow/PhysicoNet/data/Original/S004/S004R13.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: [np.str_('both_feet'), np.str_('both_fist'), np.str_('rest')]
# Not setting metadata
# 30 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 30 events and 113 original time points ...
# 1 bad epochs dropped
# {'T0': 'rest', 'T1': 'both_fist', 'T2': 'both_feet'}
# Processing: ../data/Original/S004/S004R14.edf
# Extracting EDF parameters from /Users/kavisanthoshkumar/Library/CloudStorage/OneDrive-IllinoisInstituteofTechnology/Tensorflow/PhysicoNet/data/Original/S004/S004R14.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: [np.str_('both_feet'), np.str_('both_fist'), np.str_('rest')]
# Not setting metadata
# 30 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 30 events and 113 original time points ...
# 1 bad epochs dropped
# {'T0': 'rest', 'T1': 'NA', 'T2': 'NA'}
# Processing: ../data/Original/S005/S005R01.edf
# Extracting EDF parameters from /Users/kavisanthoshkumar/Library/CloudStorage/OneDrive-IllinoisInstituteofTechnology/Tensorflow/PhysicoNet/data/Original/S005/S005R01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# Used Annotations descriptions: [np.str_('rest')]
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 113 original time points ...
# 1 bad epochs dropped
# {'T0': 'rest', 'T1': 'NA', 'T2': 'NA'}
# Processing: ../data/Original/S005/S005R02.edf
# Extracting EDF parameters from /Users/kavisanthoshkumar/Library/CloudStorage/OneDrive-IllinoisInstituteofTechnology/Tensorflow/PhysicoNet/data/Original/S005/S005R02.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# Used Annotations descriptions: [np.str_('rest')]
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 113 original time points ...
# 1 bad epochs dropped
# {'T0': 'rest', 'T1': 'left_fist', 'T2': 'right_fist'}
# Processing: ../data/Original/S005/S005R03.edf
# Extracting EDF parameters from /Users/kavisanthoshkumar/Library/CloudStorage/OneDrive-IllinoisInstituteofTechnology/Tensorflow/PhysicoNet/data/Original/S005/S005R03.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: [np.str_('left_fist'), np.str_('rest'), np.str_('right_fist')]
# Not setting metadata
# 30 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 30 events and 113 original time points ...
# 1 bad epochs dropped
# {'T0': 'rest', 'T1': 'left_fist', 'T2': 'right_fist'}
# Processing: ../data/Original/S005/S005R04.edf
# Extracting EDF parameters from /Users/kavisanthoshkumar/Library/CloudStorage/OneDrive-IllinoisInstituteofTechnology/Tensorflow/PhysicoNet/data/Original/S005/S005R04.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: [np.str_('left_fist'), np.str_('rest'), np.str_('right_fist')]
# Not setting metadata
# 30 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 30 events and 113 original time points ...
# 1 bad epochs dropped
# {'T0': 'rest', 'T1': 'both_fist', 'T2': 'both_feet'}
# Processing: ../data/Original/S005/S005R05.edf
# Extracting EDF parameters from /Users/kavisanthoshkumar/Library/CloudStorage/OneDrive-IllinoisInstituteofTechnology/Tensorflow/PhysicoNet/data/Original/S005/S005R05.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: [np.str_('both_feet'), np.str_('both_fist'), np.str_('rest')]
# Not setting metadata
# 30 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 30 events and 113 original time points ...
# 1 bad epochs dropped
# {'T0': 'rest', 'T1': 'both_fist', 'T2': 'both_feet'}
# Processing: ../data/Original/S005/S005R06.edf
# Extracting EDF parameters from /Users/kavisanthoshkumar/Library/CloudStorage/OneDrive-IllinoisInstituteofTechnology/Tensorflow/PhysicoNet/data/Original/S005/S005R06.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: [np.str_('both_feet'), np.str_('both_fist'), np.str_('rest')]
# Not setting metadata
# 30 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 30 events and 113 original time points ...
# 1 bad epochs dropped
# {'T0': 'rest', 'T1': 'left_fist', 'T2': 'right_fist'}
# Processing: ../data/Original/S005/S005R07.edf
# Extracting EDF parameters from /Users/kavisanthoshkumar/Library/CloudStorage/OneDrive-IllinoisInstituteofTechnology/Tensorflow/PhysicoNet/data/Original/S005/S005R07.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: [np.str_('left_fist'), np.str_('rest'), np.str_('right_fist')]
# Not setting metadata
# 30 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 30 events and 113 original time points ...
# 1 bad epochs dropped
# {'T0': 'rest', 'T1': 'left_fist', 'T2': 'right_fist'}
# Processing: ../data/Original/S005/S005R08.edf
# Extracting EDF parameters from /Users/kavisanthoshkumar/Library/CloudStorage/OneDrive-IllinoisInstituteofTechnology/Tensorflow/PhysicoNet/data/Original/S005/S005R08.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# /var/folders/_p/pgtp_zhj7n3717r3m0prtkdh0000gn/T/ipykernel_16071/3325446389.py:85: RuntimeWarning: All epochs were dropped!
# You might need to alter reject/flat-criteria or drop bad channels to avoid this. You can use Epochs.plot_drop_log() to see which channels are responsible for the dropping of epochs.
#   epochs = mne.Epochs(
# /var/folders/_p/pgtp_zhj7n3717r3m0prtkdh0000gn/T/ipykernel_16071/3325446389.py:85: RuntimeWarning: All epochs were dropped!
# You might need to alter reject/flat-criteria or drop bad channels to avoid this. You can use Epochs.plot_drop_log() to see which channels are responsible for the dropping of epochs.
#   epochs = mne.Epochs(
# Used Annotations descriptions: [np.str_('left_fist'), np.str_('rest'), np.str_('right_fist')]
# Not setting metadata
# 30 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 30 events and 113 original time points ...
# 1 bad epochs dropped
# ...
# Extracting EDF parameters from /Users/kavisanthoshkumar/Library/CloudStorage/OneDrive-IllinoisInstituteofTechnology/Tensorflow/PhysicoNet/data/Original/S108/S108R08.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# /var/folders/_p/pgtp_zhj7n3717r3m0prtkdh0000gn/T/ipykernel_16071/3325446389.py:85: RuntimeWarning: All epochs were dropped!
# You might need to alter reject/flat-criteria or drop bad channels to avoid this. You can use Epochs.plot_drop_log() to see which channels are responsible for the dropping of epochs.
#   epochs = mne.Epochs(
# /var/folders/_p/pgtp_zhj7n3717r3m0prtkdh0000gn/T/ipykernel_16071/3325446389.py:85: RuntimeWarning: All epochs were dropped!
# You might need to alter reject/flat-criteria or drop bad channels to avoid this. You can use Epochs.plot_drop_log() to see which channels are responsible for the dropping of epochs.
#   epochs = mne.Epochs(
# Used Annotations descriptions: [np.str_('left_fist'), np.str_('rest'), np.str_('right_fist')]
# Not setting metadata
# 30 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 30 events and 113 original time points ...
# 1 bad epochs dropped
# {'T0': 'rest', 'T1': 'both_fist', 'T2': 'both_feet'}
# Processing: ../data/Original/S108/S108R09.edf
# Extracting EDF parameters from /Users/kavisanthoshkumar/Library/CloudStorage/OneDrive-IllinoisInstituteofTechnology/Tensorflow/PhysicoNet/data/Original/S108/S108R09.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: [np.str_('both_feet'), np.str_('both_fist'), np.str_('rest')]
# Not setting metadata
# 30 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 30 events and 113 original time points ...
# 1 bad epochs dropped
# {'T0': 'rest', 'T1': 'both_fist', 'T2': 'both_feet'}
# Processing: ../data/Original/S108/S108R10.edf
# Extracting EDF parameters from /Users/kavisanthoshkumar/Library/CloudStorage/OneDrive-IllinoisInstituteofTechnology/Tensorflow/PhysicoNet/data/Original/S108/S108R10.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: [np.str_('both_feet'), np.str_('both_fist'), np.str_('rest')]
# Not setting metadata
# 30 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 30 events and 113 original time points ...
# 1 bad epochs dropped
# {'T0': 'rest', 'T1': 'left_fist', 'T2': 'right_fist'}
# Processing: ../data/Original/S108/S108R11.edf
# Extracting EDF parameters from /Users/kavisanthoshkumar/Library/CloudStorage/OneDrive-IllinoisInstituteofTechnology/Tensorflow/PhysicoNet/data/Original/S108/S108R11.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: [np.str_('left_fist'), np.str_('rest'), np.str_('right_fist')]
# Not setting metadata
# 30 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 30 events and 113 original time points ...
# 1 bad epochs dropped
# {'T0': 'rest', 'T1': 'left_fist', 'T2': 'right_fist'}
# Processing: ../data/Original/S108/S108R12.edf
# Extracting EDF parameters from /Users/kavisanthoshkumar/Library/CloudStorage/OneDrive-IllinoisInstituteofTechnology/Tensorflow/PhysicoNet/data/Original/S108/S108R12.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: [np.str_('left_fist'), np.str_('rest'), np.str_('right_fist')]
# Not setting metadata
# 30 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 30 events and 113 original time points ...
# 1 bad epochs dropped
# {'T0': 'rest', 'T1': 'both_fist', 'T2': 'both_feet'}
# Processing: ../data/Original/S108/S108R13.edf
# Extracting EDF parameters from /Users/kavisanthoshkumar/Library/CloudStorage/OneDrive-IllinoisInstituteofTechnology/Tensorflow/PhysicoNet/data/Original/S108/S108R13.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: [np.str_('both_feet'), np.str_('both_fist'), np.str_('rest')]
# Not setting metadata
# 30 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 30 events and 113 original time points ...
# 1 bad epochs dropped
# {'T0': 'rest', 'T1': 'both_fist', 'T2': 'both_feet'}
# Processing: ../data/Original/S108/S108R14.edf
# Extracting EDF parameters from /Users/kavisanthoshkumar/Library/CloudStorage/OneDrive-IllinoisInstituteofTechnology/Tensorflow/PhysicoNet/data/Original/S108/S108R14.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: [np.str_('both_feet'), np.str_('both_fist'), np.str_('rest')]
# Not setting metadata
# 30 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 30 events and 113 original time points ...
# 1 bad epochs dropped
# {'T0': 'rest', 'T1': 'NA', 'T2': 'NA'}
# Processing: ../data/Original/S109/S109R01.edf
# Extracting EDF parameters from /Users/kavisanthoshkumar/Library/CloudStorage/OneDrive-IllinoisInstituteofTechnology/Tensorflow/PhysicoNet/data/Original/S109/S109R01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9599  =      0.000 ...    59.994 secs...
# Used Annotations descriptions: [np.str_('rest')]
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 113 original time points ...
# 1 bad epochs dropped
# {'T0': 'rest', 'T1': 'NA', 'T2': 'NA'}
# Processing: ../data/Original/S109/S109R02.edf
# Extracting EDF parameters from /Users/kavisanthoshkumar/Library/CloudStorage/OneDrive-IllinoisInstituteofTechnology/Tensorflow/PhysicoNet/data/Original/S109/S109R02.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# Used Annotations descriptions: [np.str_('rest')]
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 113 original time points ...
# 1 bad epochs dropped
# {'T0': 'rest', 'T1': 'left_fist', 'T2': 'right_fist'}
# Processing: ../data/Original/S109/S109R03.edf
# Extracting EDF parameters from /Users/kavisanthoshkumar/Library/CloudStorage/OneDrive-IllinoisInstituteofTechnology/Tensorflow/PhysicoNet/data/Original/S109/S109R03.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: [np.str_('left_fist'), np.str_('rest'), np.str_('right_fist')]
# Not setting metadata
# 30 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 30 events and 113 original time points ...
# 1 bad epochs dropped
# {'T0': 'rest', 'T1': 'left_fist', 'T2': 'right_fist'}
# Processing: ../data/Original/S109/S109R04.edf
# Extracting EDF parameters from /Users/kavisanthoshkumar/Library/CloudStorage/OneDrive-IllinoisInstituteofTechnology/Tensorflow/PhysicoNet/data/Original/S109/S109R04.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: [np.str_('left_fist'), np.str_('rest'), np.str_('right_fist')]
# Not setting metadata
# 30 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 30 events and 113 original time points ...
# 1 bad epochs dropped
# {'T0': 'rest', 'T1': 'both_fist', 'T2': 'both_feet'}
# Processing: ../data/Original/S109/S109R05.edf
# Extracting EDF parameters from /Users/kavisanthoshkumar/Library/CloudStorage/OneDrive-IllinoisInstituteofTechnology/Tensorflow/PhysicoNet/data/Original/S109/S109R05.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: [np.str_('both_feet'), np.str_('both_fist'), np.str_('rest')]
# Not setting metadata
# 30 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 30 events and 113 original time points ...
# 1 bad epochs dropped
# {'T0': 'rest', 'T1': 'both_fist', 'T2': 'both_feet'}
# Processing: ../data/Original/S109/S109R06.edf
# Extracting EDF parameters from /Users/kavisanthoshkumar/Library/CloudStorage/OneDrive-IllinoisInstituteofTechnology/Tensorflow/PhysicoNet/data/Original/S109/S109R06.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: [np.str_('both_feet'), np.str_('both_fist'), np.str_('rest')]
# Not setting metadata
# 30 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 30 events and 113 original time points ...
# 1 bad epochs dropped
# {'T0': 'rest', 'T1': 'left_fist', 'T2': 'right_fist'}
# Processing: ../data/Original/S109/S109R07.edf
# Extracting EDF parameters from /Users/kavisanthoshkumar/Library/CloudStorage/OneDrive-IllinoisInstituteofTechnology/Tensorflow/PhysicoNet/data/Original/S109/S109R07.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: [np.str_('left_fist'), np.str_('rest'), np.str_('right_fist')]
# Not setting metadata
# 30 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 30 events and 113 original time points ...
# 1 bad epochs dropped
# {'T0': 'rest', 'T1': 'left_fist', 'T2': 'right_fist'}
# Processing: ../data/Original/S109/S109R08.edf
# Extracting EDF parameters from /Users/kavisanthoshkumar/Library/CloudStorage/OneDrive-IllinoisInstituteofTechnology/Tensorflow/PhysicoNet/data/Original/S109/S109R08.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# /var/folders/_p/pgtp_zhj7n3717r3m0prtkdh0000gn/T/ipykernel_16071/3325446389.py:85: RuntimeWarning: All epochs were dropped!
# You might need to alter reject/flat-criteria or drop bad channels to avoid this. You can use Epochs.plot_drop_log() to see which channels are responsible for the dropping of epochs.
#   epochs = mne.Epochs(
# /var/folders/_p/pgtp_zhj7n3717r3m0prtkdh0000gn/T/ipykernel_16071/3325446389.py:85: RuntimeWarning: All epochs were dropped!
# You might need to alter reject/flat-criteria or drop bad channels to avoid this. You can use Epochs.plot_drop_log() to see which channels are responsible for the dropping of epochs.
#   epochs = mne.Epochs(
# Used Annotations descriptions: [np.str_('left_fist'), np.str_('rest'), np.str_('right_fist')]
# Not setting metadata
# 30 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 30 events and 113 original time points ...
# 1 bad epochs dropped
# {'T0': 'rest', 'T1': 'both_fist', 'T2': 'both_feet'}
# Processing: ../data/Original/S109/S109R09.edf
# Extracting EDF parameters from /Users/kavisanthoshkumar/Library/CloudStorage/OneDrive-IllinoisInstituteofTechnology/Tensorflow/PhysicoNet/data/Original/S109/S109R09.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: [np.str_('both_feet'), np.str_('both_fist'), np.str_('rest')]
# Not setting metadata
# 30 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 30 events and 113 original time points ...
# 1 bad epochs dropped
# {'T0': 'rest', 'T1': 'both_fist', 'T2': 'both_feet'}
# Processing: ../data/Original/S109/S109R10.edf
# Extracting EDF parameters from /Users/kavisanthoshkumar/Library/CloudStorage/OneDrive-IllinoisInstituteofTechnology/Tensorflow/PhysicoNet/data/Original/S109/S109R10.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: [np.str_('both_feet'), np.str_('both_fist'), np.str_('rest')]
# Not setting metadata
# 30 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 30 events and 113 original time points ...
# 1 bad epochs dropped
# {'T0': 'rest', 'T1': 'left_fist', 'T2': 'right_fist'}
# Processing: ../data/Original/S109/S109R11.edf
# Extracting EDF parameters from /Users/kavisanthoshkumar/Library/CloudStorage/OneDrive-IllinoisInstituteofTechnology/Tensorflow/PhysicoNet/data/Original/S109/S109R11.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: [np.str_('left_fist'), np.str_('rest'), np.str_('right_fist')]
# Not setting metadata
# 30 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 30 events and 113 original time points ...
# 1 bad epochs dropped
# {'T0': 'rest', 'T1': 'left_fist', 'T2': 'right_fist'}
# Processing: ../data/Original/S109/S109R12.edf
# Extracting EDF parameters from /Users/kavisanthoshkumar/Library/CloudStorage/OneDrive-IllinoisInstituteofTechnology/Tensorflow/PhysicoNet/data/Original/S109/S109R12.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: [np.str_('left_fist'), np.str_('rest'), np.str_('right_fist')]
# Not setting metadata
# 30 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 30 events and 113 original time points ...
# 1 bad epochs dropped
# {'T0': 'rest', 'T1': 'both_fist', 'T2': 'both_feet'}
# Processing: ../data/Original/S109/S109R13.edf
# Extracting EDF parameters from /Users/kavisanthoshkumar/Library/CloudStorage/OneDrive-IllinoisInstituteofTechnology/Tensorflow/PhysicoNet/data/Original/S109/S109R13.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: [np.str_('both_feet'), np.str_('both_fist'), np.str_('rest')]
# Not setting metadata
# 30 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 30 events and 113 original time points ...
# 1 bad epochs dropped
# {'T0': 'rest', 'T1': 'both_fist', 'T2': 'both_feet'}
# Processing: ../data/Original/S109/S109R14.edf
# Extracting EDF parameters from /Users/kavisanthoshkumar/Library/CloudStorage/OneDrive-IllinoisInstituteofTechnology/Tensorflow/PhysicoNet/data/Original/S109/S109R14.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: [np.str_('both_feet'), np.str_('both_fist'), np.str_('rest')]
# Not setting metadata
# 30 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 30 events and 113 original time points ...
# 1 bad epochs dropped
#
# Total EDF files processed: 1526

# %% [markdown]
# # Extracting Data - X, Y

# %%
X, y, groups = [], [], []

for group_id, epochs in enumerate(all_epochs):
    try:
        print(f"Processing participant #{group_id}")

        # Skip empty or invalid epochs
        if len(epochs) == 0:
            print(f"Skipping participant #{group_id}: empty epochs")
            continue

        # Extract data
        X_epoch = epochs.get_data()  # shape: (n_epochs, n_channels, n_times)
        y_epoch_event_mapping = epochs.event_id
        y_epoch = epochs.events[:, 2]  # event ids

        # Map event codes to labels (string form)
        y_epoch = np.array(y_epoch, dtype=object)
        for key, value in y_epoch_event_mapping.items():
            y_epoch[y_epoch == value] = str(key)

        # Add group info
        group_epoch = [group_id] * len(y_epoch)

        # Append
        X.append(X_epoch)
        y.extend(y_epoch)
        groups.extend(group_epoch)

    except Exception as e:
        print(f"Error processing participant #{group_id}: {e}")
        continue

# --- Align time dimension before concatenation ---
if len(X) == 0:
    X = np.empty((0, 64, 113))  # fallback shape
else:
    # Find min time dimension
    min_time = min(x.shape[2] for x in X)
    print(f"Aligning all epochs to {min_time} time samples")

    # Truncate each to same time length
    X = [x[:, :, :min_time] for x in X]

    # Safe concatenation
    X = np.concatenate(X, axis=0)

y = np.array(y, dtype=object)
groups = np.array(groups)

print("Final shapes:")
print("X:", X.shape)
print("y:", y.shape)
print("groups:", groups.shape)
# Out:
# Processing participant #0
# Skipping participant #0: empty epochs
# Processing participant #1
# Skipping participant #1: empty epochs
# Processing participant #2
# Processing participant #3
# Processing participant #4
# Processing participant #5
# Processing participant #6
# Processing participant #7
# Processing participant #8
# Processing participant #9
# Processing participant #10
# Processing participant #11
# Processing participant #12
# Processing participant #13
# Processing participant #14
# Skipping participant #14: empty epochs
# Processing participant #15
# Skipping participant #15: empty epochs
# Processing participant #16
# Processing participant #17
# Processing participant #18
# Processing participant #19
# Processing participant #20
# Processing participant #21
# Processing participant #22
# Processing participant #23
# Processing participant #24
# Processing participant #25
# Processing participant #26
# Processing participant #27
# Processing participant #28
# Skipping participant #28: empty epochs
# Processing participant #29
# Skipping participant #29: empty epochs
# Processing participant #30
# Processing participant #31
# Processing participant #32
# Processing participant #33
# Processing participant #34
# Processing participant #35
# Processing participant #36
# Processing participant #37
# Processing participant #38
# Processing participant #39
# Processing participant #40
# Processing participant #41
# Processing participant #42
# Skipping participant #42: empty epochs
# Processing participant #43
# Skipping participant #43: empty epochs
# Processing participant #44
# Processing participant #45
# Processing participant #46
# Processing participant #47
# Processing participant #48
# Processing participant #49
# Processing participant #50
# Processing participant #51
# Processing participant #52
# Processing participant #53
# Processing participant #54
# Processing participant #55
# Processing participant #56
# Skipping participant #56: empty epochs
# Processing participant #57
# Skipping participant #57: empty epochs
# Processing participant #58
# Processing participant #59
# Processing participant #60
# Processing participant #61
# Processing participant #62
# Processing participant #63
# Processing participant #64
# Processing participant #65
# Processing participant #66
# Processing participant #67
# Processing participant #68
# Processing participant #69
# Processing participant #70
# Skipping participant #70: empty epochs
# Processing participant #71
# Skipping participant #71: empty epochs
# Processing participant #72
# Processing participant #73
# Processing participant #74
# Processing participant #75
# Processing participant #76
# Processing participant #77
# Processing participant #78
# Processing participant #79
# Processing participant #80
# Processing participant #81
# Processing participant #82
# Processing participant #83
# Processing participant #84
# Skipping participant #84: empty epochs
# Processing participant #85
# Skipping participant #85: empty epochs
# Processing participant #86
# Processing participant #87
# Processing participant #88
# Processing participant #89
# Processing participant #90
# Processing participant #91
# Processing participant #92
# Processing participant #93
# Processing participant #94
# Processing participant #95
# Processing participant #96
# Processing participant #97
# Processing participant #98
# Skipping participant #98: empty epochs
# Processing participant #99
# Skipping participant #99: empty epochs
# Processing participant #100
# Processing participant #101
# Processing participant #102
# Processing participant #103
# Processing participant #104
# Processing participant #105
# Processing participant #106
# Processing participant #107
# Processing participant #108
# Processing participant #109
# Processing participant #110
# Processing participant #111
# Processing participant #112
# Skipping participant #112: empty epochs
# Processing participant #113
# Skipping participant #113: empty epochs
# Processing participant #114
# Processing participant #115
# Processing participant #116
# Processing participant #117
# Processing participant #118
# Processing participant #119
# Processing participant #120
# Processing participant #121
# Processing participant #122
# Processing participant #123
# Processing participant #124
# Processing participant #125
# Processing participant #126
# Skipping participant #126: empty epochs
# Processing participant #127
# Skipping participant #127: empty epochs
# Processing participant #128
# Processing participant #129
# Processing participant #130
# Processing participant #131
# Processing participant #132
# Processing participant #133
# Processing participant #134
# Processing participant #135
# Processing participant #136
# Processing participant #137
# Processing participant #138
# Processing participant #139
# Processing participant #140
# Skipping participant #140: empty epochs
# Processing participant #141
# Skipping participant #141: empty epochs
# Processing participant #142
# Processing participant #143
# Processing participant #144
# Processing participant #145
# Processing participant #146
# Processing participant #147
# Processing participant #148
# Processing participant #149
# Processing participant #150
# Processing participant #151
# Processing participant #152
# Processing participant #153
# Processing participant #154
# Skipping participant #154: empty epochs
# Processing participant #155
# Skipping participant #155: empty epochs
# Processing participant #156
# Processing participant #157
# Processing participant #158
# Processing participant #159
# Processing participant #160
# Processing participant #161
# Processing participant #162
# Processing participant #163
# Processing participant #164
# Processing participant #165
# Processing participant #166
# Processing participant #167
# Processing participant #168
# Skipping participant #168: empty epochs
# Processing participant #169
# Skipping participant #169: empty epochs
# Processing participant #170
# Processing participant #171
# Processing participant #172
# Processing participant #173
# Processing participant #174
# Processing participant #175
# Processing participant #176
# Processing participant #177
# Processing participant #178
# Processing participant #179
# Processing participant #180
# Processing participant #181
# Processing participant #182
# Skipping participant #182: empty epochs
# Processing participant #183
# Skipping participant #183: empty epochs
# Processing participant #184
# Processing participant #185
# Processing participant #186
# Processing participant #187
# Processing participant #188
# Processing participant #189
# Processing participant #190
# Processing participant #191
# Processing participant #192
# Processing participant #193
# Processing participant #194
# Processing participant #195
# Processing participant #196
# Skipping participant #196: empty epochs
# Processing participant #197
# Skipping participant #197: empty epochs
# Processing participant #198
# Processing participant #199
# Processing participant #200
# Processing participant #201
# Processing participant #202
# Processing participant #203
# Processing participant #204
# Processing participant #205
# Processing participant #206
# Processing participant #207
# Processing participant #208
# Processing participant #209
# Processing participant #210
# Skipping participant #210: empty epochs
# Processing participant #211
# Skipping participant #211: empty epochs
# Processing participant #212
# Processing participant #213
# Processing participant #214
# Processing participant #215
# Processing participant #216
# Processing participant #217
# Processing participant #218
# Processing participant #219
# Processing participant #220
# Processing participant #221
# Processing participant #222
# Processing participant #223
# Processing participant #224
# Skipping participant #224: empty epochs
# Processing participant #225
# Skipping participant #225: empty epochs
# Processing participant #226
# Processing participant #227
# Processing participant #228
# Processing participant #229
# Processing participant #230
# Processing participant #231
# Processing participant #232
# Processing participant #233
# Processing participant #234
# Processing participant #235
# Processing participant #236
# Processing participant #237
# Processing participant #238
# Skipping participant #238: empty epochs
# Processing participant #239
# Skipping participant #239: empty epochs
# Processing participant #240
# Processing participant #241
# Processing participant #242
# Processing participant #243
# Processing participant #244
# Processing participant #245
# Processing participant #246
# Processing participant #247
# Processing participant #248
# Processing participant #249
# Processing participant #250
# Processing participant #251
# Processing participant #252
# Skipping participant #252: empty epochs
# Processing participant #253
# Skipping participant #253: empty epochs
# Processing participant #254
# Processing participant #255
# Processing participant #256
# Processing participant #257
# Processing participant #258
# Processing participant #259
# Processing participant #260
# Processing participant #261
# Processing participant #262
# Processing participant #263
# Processing participant #264
# Processing participant #265
# Processing participant #266
# Skipping participant #266: empty epochs
# Processing participant #267
# Skipping participant #267: empty epochs
# Processing participant #268
# Processing participant #269
# Processing participant #270
# Processing participant #271
# Processing participant #272
# Processing participant #273
# Processing participant #274
# Processing participant #275
# Processing participant #276
# Processing participant #277
# Processing participant #278
# Processing participant #279
# Processing participant #280
# Skipping participant #280: empty epochs
# Processing participant #281
# Skipping participant #281: empty epochs
# Processing participant #282
# Processing participant #283
# Processing participant #284
# Processing participant #285
# Processing participant #286
# Processing participant #287
# Processing participant #288
# Processing participant #289
# Processing participant #290
# Processing participant #291
# Processing participant #292
# Processing participant #293
# Processing participant #294
# Skipping participant #294: empty epochs
# Processing participant #295
# Skipping participant #295: empty epochs
# Processing participant #296
# Processing participant #297
# Processing participant #298
# Processing participant #299
# Processing participant #300
# Processing participant #301
# Processing participant #302
# Processing participant #303
# Processing participant #304
# Processing participant #305
# Processing participant #306
# Processing participant #307
# Processing participant #308
# Skipping participant #308: empty epochs
# Processing participant #309
# Skipping participant #309: empty epochs
# Processing participant #310
# Processing participant #311
# Processing participant #312
# Processing participant #313
# Processing participant #314
# Processing participant #315
# Processing participant #316
# Processing participant #317
# Processing participant #318
# Processing participant #319
# Processing participant #320
# Processing participant #321
# Processing participant #322
# Skipping participant #322: empty epochs
# Processing participant #323
# Skipping participant #323: empty epochs
# Processing participant #324
# Processing participant #325
# Processing participant #326
# Processing participant #327
# Processing participant #328
# Processing participant #329
# Processing participant #330
# Processing participant #331
# Processing participant #332
# Processing participant #333
# Processing participant #334
# Processing participant #335
# Processing participant #336
# Skipping participant #336: empty epochs
# Processing participant #337
# Skipping participant #337: empty epochs
# Processing participant #338
# Processing participant #339
# Processing participant #340
# Processing participant #341
# Processing participant #342
# Processing participant #343
# Processing participant #344
# Processing participant #345
# Processing participant #346
# Processing participant #347
# Processing participant #348
# Processing participant #349
# Processing participant #350
# Skipping participant #350: empty epochs
# Processing participant #351
# Skipping participant #351: empty epochs
# Processing participant #352
# Processing participant #353
# Processing participant #354
# Processing participant #355
# Processing participant #356
# Processing participant #357
# Processing participant #358
# Processing participant #359
# Processing participant #360
# Processing participant #361
# Processing participant #362
# Processing participant #363
# Processing participant #364
# Skipping participant #364: empty epochs
# Processing participant #365
# Skipping participant #365: empty epochs
# Processing participant #366
# Processing participant #367
# Processing participant #368
# Processing participant #369
# Processing participant #370
# Processing participant #371
# Processing participant #372
# Processing participant #373
# Processing participant #374
# Processing participant #375
# Processing participant #376
# Processing participant #377
# Processing participant #378
# Skipping participant #378: empty epochs
# Processing participant #379
# Skipping participant #379: empty epochs
# Processing participant #380
# Processing participant #381
# Processing participant #382
# Processing participant #383
# Processing participant #384
# Processing participant #385
# Processing participant #386
# Processing participant #387
# Processing participant #388
# Processing participant #389
# Processing participant #390
# Processing participant #391
# Processing participant #392
# Skipping participant #392: empty epochs
# Processing participant #393
# Skipping participant #393: empty epochs
# Processing participant #394
# Processing participant #395
# Processing participant #396
# Processing participant #397
# Processing participant #398
# Processing participant #399
# Processing participant #400
# Processing participant #401
# Processing participant #402
# Processing participant #403
# Processing participant #404
# Processing participant #405
# Processing participant #406
# Skipping participant #406: empty epochs
# Processing participant #407
# Skipping participant #407: empty epochs
# Processing participant #408
# Processing participant #409
# Processing participant #410
# Processing participant #411
# Processing participant #412
# Processing participant #413
# Processing participant #414
# Processing participant #415
# Processing participant #416
# Processing participant #417
# Processing participant #418
# Processing participant #419
# Processing participant #420
# Skipping participant #420: empty epochs
# Processing participant #421
# Skipping participant #421: empty epochs
# Processing participant #422
# Processing participant #423
# Processing participant #424
# Processing participant #425
# Processing participant #426
# Processing participant #427
# Processing participant #428
# Processing participant #429
# Processing participant #430
# Processing participant #431
# Processing participant #432
# Processing participant #433
# Processing participant #434
# Skipping participant #434: empty epochs
# Processing participant #435
# Skipping participant #435: empty epochs
# Processing participant #436
# Processing participant #437
# Processing participant #438
# Processing participant #439
# Processing participant #440
# Processing participant #441
# Processing participant #442
# Processing participant #443
# Processing participant #444
# Processing participant #445
# Processing participant #446
# Processing participant #447
# Processing participant #448
# Skipping participant #448: empty epochs
# Processing participant #449
# Skipping participant #449: empty epochs
# Processing participant #450
# Processing participant #451
# Processing participant #452
# Processing participant #453
# Processing participant #454
# Processing participant #455
# Processing participant #456
# Processing participant #457
# Processing participant #458
# Processing participant #459
# Processing participant #460
# Processing participant #461
# Processing participant #462
# Skipping participant #462: empty epochs
# Processing participant #463
# Skipping participant #463: empty epochs
# Processing participant #464
# Processing participant #465
# Processing participant #466
# Processing participant #467
# Processing participant #468
# Processing participant #469
# Processing participant #470
# Processing participant #471
# Processing participant #472
# Processing participant #473
# Processing participant #474
# Processing participant #475
# Processing participant #476
# Skipping participant #476: empty epochs
# Processing participant #477
# Skipping participant #477: empty epochs
# Processing participant #478
# Processing participant #479
# Processing participant #480
# Processing participant #481
# Processing participant #482
# Processing participant #483
# Processing participant #484
# Processing participant #485
# Processing participant #486
# Processing participant #487
# Processing participant #488
# Processing participant #489
# Processing participant #490
# Skipping participant #490: empty epochs
# Processing participant #491
# Skipping participant #491: empty epochs
# Processing participant #492
# Processing participant #493
# Processing participant #494
# Processing participant #495
# Processing participant #496
# Processing participant #497
# Processing participant #498
# Processing participant #499
# Processing participant #500
# Processing participant #501
# Processing participant #502
# Processing participant #503
# Processing participant #504
# Skipping participant #504: empty epochs
# Processing participant #505
# Skipping participant #505: empty epochs
# Processing participant #506
# Processing participant #507
# Processing participant #508
# Processing participant #509
# Processing participant #510
# Processing participant #511
# Processing participant #512
# Processing participant #513
# Processing participant #514
# Processing participant #515
# Processing participant #516
# Processing participant #517
# Processing participant #518
# Skipping participant #518: empty epochs
# Processing participant #519
# Skipping participant #519: empty epochs
# Processing participant #520
# Processing participant #521
# Processing participant #522
# Processing participant #523
# Processing participant #524
# Processing participant #525
# Processing participant #526
# Processing participant #527
# Processing participant #528
# Processing participant #529
# Processing participant #530
# Processing participant #531
# Processing participant #532
# Skipping participant #532: empty epochs
# Processing participant #533
# Skipping participant #533: empty epochs
# Processing participant #534
# Processing participant #535
# Processing participant #536
# Processing participant #537
# Processing participant #538
# Processing participant #539
# Processing participant #540
# Processing participant #541
# Processing participant #542
# Processing participant #543
# Processing participant #544
# Processing participant #545
# Processing participant #546
# Skipping participant #546: empty epochs
# Processing participant #547
# Skipping participant #547: empty epochs
# Processing participant #548
# Processing participant #549
# Processing participant #550
# Processing participant #551
# Processing participant #552
# Processing participant #553
# Processing participant #554
# Processing participant #555
# Processing participant #556
# Processing participant #557
# Processing participant #558
# Processing participant #559
# Processing participant #560
# Skipping participant #560: empty epochs
# Processing participant #561
# Skipping participant #561: empty epochs
# Processing participant #562
# Processing participant #563
# Processing participant #564
# Processing participant #565
# Processing participant #566
# Processing participant #567
# Processing participant #568
# Processing participant #569
# Processing participant #570
# Processing participant #571
# Processing participant #572
# Processing participant #573
# Processing participant #574
# Skipping participant #574: empty epochs
# Processing participant #575
# Skipping participant #575: empty epochs
# Processing participant #576
# Processing participant #577
# Processing participant #578
# Processing participant #579
# Processing participant #580
# Processing participant #581
# Processing participant #582
# Processing participant #583
# Processing participant #584
# Processing participant #585
# Processing participant #586
# Processing participant #587
# Processing participant #588
# Skipping participant #588: empty epochs
# Processing participant #589
# Skipping participant #589: empty epochs
# Processing participant #590
# Processing participant #591
# Processing participant #592
# Processing participant #593
# Processing participant #594
# Processing participant #595
# Processing participant #596
# Processing participant #597
# Processing participant #598
# Processing participant #599
# Processing participant #600
# Processing participant #601
# Processing participant #602
# Skipping participant #602: empty epochs
# Processing participant #603
# Skipping participant #603: empty epochs
# Processing participant #604
# Processing participant #605
# Processing participant #606
# Processing participant #607
# Processing participant #608
# Processing participant #609
# Processing participant #610
# Processing participant #611
# Processing participant #612
# Processing participant #613
# Processing participant #614
# Processing participant #615
# Processing participant #616
# Skipping participant #616: empty epochs
# Processing participant #617
# Skipping participant #617: empty epochs
# Processing participant #618
# Processing participant #619
# Processing participant #620
# Processing participant #621
# Processing participant #622
# Processing participant #623
# Processing participant #624
# Processing participant #625
# Processing participant #626
# Processing participant #627
# Processing participant #628
# Processing participant #629
# Processing participant #630
# Skipping participant #630: empty epochs
# Processing participant #631
# Skipping participant #631: empty epochs
# Processing participant #632
# Processing participant #633
# Processing participant #634
# Processing participant #635
# Processing participant #636
# Processing participant #637
# Processing participant #638
# Processing participant #639
# Processing participant #640
# Processing participant #641
# Processing participant #642
# Processing participant #643
# Processing participant #644
# Skipping participant #644: empty epochs
# Processing participant #645
# Skipping participant #645: empty epochs
# Processing participant #646
# Processing participant #647
# Processing participant #648
# Processing participant #649
# Processing participant #650
# Processing participant #651
# Processing participant #652
# Processing participant #653
# Processing participant #654
# Processing participant #655
# Processing participant #656
# Processing participant #657
# Processing participant #658
# Skipping participant #658: empty epochs
# Processing participant #659
# Skipping participant #659: empty epochs
# Processing participant #660
# Processing participant #661
# Processing participant #662
# Processing participant #663
# Processing participant #664
# Processing participant #665
# Processing participant #666
# Processing participant #667
# Processing participant #668
# Processing participant #669
# Processing participant #670
# Processing participant #671
# Processing participant #672
# Skipping participant #672: empty epochs
# Processing participant #673
# Skipping participant #673: empty epochs
# Processing participant #674
# Processing participant #675
# Processing participant #676
# Processing participant #677
# Processing participant #678
# Processing participant #679
# Processing participant #680
# Processing participant #681
# Processing participant #682
# Processing participant #683
# Processing participant #684
# Processing participant #685
# Processing participant #686
# Skipping participant #686: empty epochs
# Processing participant #687
# Skipping participant #687: empty epochs
# Processing participant #688
# Processing participant #689
# Processing participant #690
# Processing participant #691
# Processing participant #692
# Processing participant #693
# Processing participant #694
# Processing participant #695
# Processing participant #696
# Processing participant #697
# Processing participant #698
# Processing participant #699
# Processing participant #700
# Skipping participant #700: empty epochs
# Processing participant #701
# Skipping participant #701: empty epochs
# Processing participant #702
# Processing participant #703
# Processing participant #704
# Processing participant #705
# Processing participant #706
# Processing participant #707
# Processing participant #708
# Processing participant #709
# Processing participant #710
# Processing participant #711
# Processing participant #712
# Processing participant #713
# Processing participant #714
# Skipping participant #714: empty epochs
# Processing participant #715
# Skipping participant #715: empty epochs
# Processing participant #716
# Processing participant #717
# Processing participant #718
# Processing participant #719
# Processing participant #720
# Processing participant #721
# Processing participant #722
# Processing participant #723
# Processing participant #724
# Processing participant #725
# Processing participant #726
# Processing participant #727
# Processing participant #728
# Skipping participant #728: empty epochs
# Processing participant #729
# Skipping participant #729: empty epochs
# Processing participant #730
# Processing participant #731
# Processing participant #732
# Processing participant #733
# Processing participant #734
# Processing participant #735
# Processing participant #736
# Processing participant #737
# Processing participant #738
# Processing participant #739
# Processing participant #740
# Processing participant #741
# Processing participant #742
# Skipping participant #742: empty epochs
# Processing participant #743
# Skipping participant #743: empty epochs
# Processing participant #744
# Processing participant #745
# Processing participant #746
# Processing participant #747
# Processing participant #748
# Processing participant #749
# Processing participant #750
# Processing participant #751
# Processing participant #752
# Processing participant #753
# Processing participant #754
# Processing participant #755
# Processing participant #756
# Skipping participant #756: empty epochs
# Processing participant #757
# Skipping participant #757: empty epochs
# Processing participant #758
# Processing participant #759
# Processing participant #760
# Processing participant #761
# Processing participant #762
# Processing participant #763
# Processing participant #764
# Processing participant #765
# Processing participant #766
# Processing participant #767
# Processing participant #768
# Processing participant #769
# Processing participant #770
# Skipping participant #770: empty epochs
# Processing participant #771
# Skipping participant #771: empty epochs
# Processing participant #772
# Processing participant #773
# Processing participant #774
# Processing participant #775
# Processing participant #776
# Processing participant #777
# Processing participant #778
# Processing participant #779
# Processing participant #780
# Processing participant #781
# Processing participant #782
# Processing participant #783
# Processing participant #784
# Skipping participant #784: empty epochs
# Processing participant #785
# Skipping participant #785: empty epochs
# Processing participant #786
# Processing participant #787
# Processing participant #788
# Processing participant #789
# Processing participant #790
# Processing participant #791
# Processing participant #792
# Processing participant #793
# Processing participant #794
# Processing participant #795
# Processing participant #796
# Processing participant #797
# Processing participant #798
# Skipping participant #798: empty epochs
# Processing participant #799
# Skipping participant #799: empty epochs
# Processing participant #800
# Processing participant #801
# Processing participant #802
# Processing participant #803
# Processing participant #804
# Processing participant #805
# Processing participant #806
# Processing participant #807
# Processing participant #808
# Processing participant #809
# Processing participant #810
# Processing participant #811
# Processing participant #812
# Skipping participant #812: empty epochs
# Processing participant #813
# Skipping participant #813: empty epochs
# Processing participant #814
# Processing participant #815
# Processing participant #816
# Processing participant #817
# Processing participant #818
# Processing participant #819
# Processing participant #820
# Processing participant #821
# Processing participant #822
# Processing participant #823
# Processing participant #824
# Processing participant #825
# Processing participant #826
# Skipping participant #826: empty epochs
# Processing participant #827
# Skipping participant #827: empty epochs
# Processing participant #828
# Processing participant #829
# Processing participant #830
# Processing participant #831
# Processing participant #832
# Processing participant #833
# Processing participant #834
# Processing participant #835
# Processing participant #836
# Processing participant #837
# Processing participant #838
# Processing participant #839
# Processing participant #840
# Skipping participant #840: empty epochs
# Processing participant #841
# Skipping participant #841: empty epochs
# Processing participant #842
# Processing participant #843
# Processing participant #844
# Processing participant #845
# Processing participant #846
# Processing participant #847
# Processing participant #848
# Processing participant #849
# Processing participant #850
# Processing participant #851
# Processing participant #852
# Processing participant #853
# Processing participant #854
# Skipping participant #854: empty epochs
# Processing participant #855
# Skipping participant #855: empty epochs
# Processing participant #856
# Processing participant #857
# Processing participant #858
# Processing participant #859
# Processing participant #860
# Processing participant #861
# Processing participant #862
# Processing participant #863
# Processing participant #864
# Processing participant #865
# Processing participant #866
# Processing participant #867
# Processing participant #868
# Skipping participant #868: empty epochs
# Processing participant #869
# Skipping participant #869: empty epochs
# Processing participant #870
# Processing participant #871
# Processing participant #872
# Processing participant #873
# Processing participant #874
# Processing participant #875
# Processing participant #876
# Processing participant #877
# Processing participant #878
# Processing participant #879
# Processing participant #880
# Processing participant #881
# Processing participant #882
# Skipping participant #882: empty epochs
# Processing participant #883
# Skipping participant #883: empty epochs
# Processing participant #884
# Processing participant #885
# Processing participant #886
# Processing participant #887
# Processing participant #888
# Processing participant #889
# Processing participant #890
# Processing participant #891
# Processing participant #892
# Processing participant #893
# Processing participant #894
# Processing participant #895
# Processing participant #896
# Skipping participant #896: empty epochs
# Processing participant #897
# Skipping participant #897: empty epochs
# Processing participant #898
# Processing participant #899
# Processing participant #900
# Processing participant #901
# Processing participant #902
# Processing participant #903
# Processing participant #904
# Processing participant #905
# Processing participant #906
# Processing participant #907
# Processing participant #908
# Processing participant #909
# Processing participant #910
# Skipping participant #910: empty epochs
# Processing participant #911
# Skipping participant #911: empty epochs
# Processing participant #912
# Processing participant #913
# Processing participant #914
# Processing participant #915
# Processing participant #916
# Processing participant #917
# Processing participant #918
# Processing participant #919
# Processing participant #920
# Processing participant #921
# Processing participant #922
# Processing participant #923
# Processing participant #924
# Skipping participant #924: empty epochs
# Processing participant #925
# Skipping participant #925: empty epochs
# Processing participant #926
# Processing participant #927
# Processing participant #928
# Processing participant #929
# Processing participant #930
# Processing participant #931
# Processing participant #932
# Processing participant #933
# Processing participant #934
# Processing participant #935
# Processing participant #936
# Processing participant #937
# Processing participant #938
# Skipping participant #938: empty epochs
# Processing participant #939
# Skipping participant #939: empty epochs
# Processing participant #940
# Processing participant #941
# Processing participant #942
# Processing participant #943
# Processing participant #944
# Processing participant #945
# Processing participant #946
# Processing participant #947
# Processing participant #948
# Processing participant #949
# Processing participant #950
# Processing participant #951
# Processing participant #952
# Skipping participant #952: empty epochs
# Processing participant #953
# Skipping participant #953: empty epochs
# Processing participant #954
# Processing participant #955
# Processing participant #956
# Processing participant #957
# Processing participant #958
# Processing participant #959
# Processing participant #960
# Processing participant #961
# Processing participant #962
# Processing participant #963
# Processing participant #964
# Processing participant #965
# Processing participant #966
# Skipping participant #966: empty epochs
# Processing participant #967
# Skipping participant #967: empty epochs
# Processing participant #968
# Processing participant #969
# Processing participant #970
# Processing participant #971
# Processing participant #972
# Processing participant #973
# Processing participant #974
# Processing participant #975
# Processing participant #976
# Processing participant #977
# Processing participant #978
# Processing participant #979
# Processing participant #980
# Skipping participant #980: empty epochs
# Processing participant #981
# Skipping participant #981: empty epochs
# Processing participant #982
# Processing participant #983
# Processing participant #984
# Processing participant #985
# Processing participant #986
# Processing participant #987
# Processing participant #988
# Processing participant #989
# Processing participant #990
# Processing participant #991
# Processing participant #992
# Processing participant #993
# Processing participant #994
# Skipping participant #994: empty epochs
# Processing participant #995
# Skipping participant #995: empty epochs
# Processing participant #996
# Processing participant #997
# Processing participant #998
# Processing participant #999
# Processing participant #1000
# Processing participant #1001
# Processing participant #1002
# Processing participant #1003
# Processing participant #1004
# Processing participant #1005
# Processing participant #1006
# Processing participant #1007
# Processing participant #1008
# Skipping participant #1008: empty epochs
# Processing participant #1009
# Skipping participant #1009: empty epochs
# Processing participant #1010
# Processing participant #1011
# Processing participant #1012
# Processing participant #1013
# Processing participant #1014
# Processing participant #1015
# Processing participant #1016
# Processing participant #1017
# Processing participant #1018
# Processing participant #1019
# Processing participant #1020
# Processing participant #1021
# Processing participant #1022
# Skipping participant #1022: empty epochs
# Processing participant #1023
# Skipping participant #1023: empty epochs
# Processing participant #1024
# Processing participant #1025
# Processing participant #1026
# Processing participant #1027
# Processing participant #1028
# Processing participant #1029
# Processing participant #1030
# Processing participant #1031
# Processing participant #1032
# Processing participant #1033
# Processing participant #1034
# Processing participant #1035
# Processing participant #1036
# Skipping participant #1036: empty epochs
# Processing participant #1037
# Skipping participant #1037: empty epochs
# Processing participant #1038
# Processing participant #1039
# Processing participant #1040
# Processing participant #1041
# Processing participant #1042
# Processing participant #1043
# Processing participant #1044
# Processing participant #1045
# Processing participant #1046
# Processing participant #1047
# Processing participant #1048
# Processing participant #1049
# Processing participant #1050
# Skipping participant #1050: empty epochs
# Processing participant #1051
# Skipping participant #1051: empty epochs
# Processing participant #1052
# Processing participant #1053
# Processing participant #1054
# Processing participant #1055
# Processing participant #1056
# Processing participant #1057
# Processing participant #1058
# Processing participant #1059
# Processing participant #1060
# Processing participant #1061
# Processing participant #1062
# Processing participant #1063
# Processing participant #1064
# Skipping participant #1064: empty epochs
# Processing participant #1065
# Skipping participant #1065: empty epochs
# Processing participant #1066
# Processing participant #1067
# Processing participant #1068
# Processing participant #1069
# Processing participant #1070
# Processing participant #1071
# Processing participant #1072
# Processing participant #1073
# Processing participant #1074
# Processing participant #1075
# Processing participant #1076
# Processing participant #1077
# Processing participant #1078
# Skipping participant #1078: empty epochs
# Processing participant #1079
# Skipping participant #1079: empty epochs
# Processing participant #1080
# Processing participant #1081
# Processing participant #1082
# Processing participant #1083
# Processing participant #1084
# Processing participant #1085
# Processing participant #1086
# Processing participant #1087
# Processing participant #1088
# Processing participant #1089
# Processing participant #1090
# Processing participant #1091
# Processing participant #1092
# Skipping participant #1092: empty epochs
# Processing participant #1093
# Skipping participant #1093: empty epochs
# Processing participant #1094
# Processing participant #1095
# Processing participant #1096
# Processing participant #1097
# Processing participant #1098
# Processing participant #1099
# Processing participant #1100
# Processing participant #1101
# Processing participant #1102
# Processing participant #1103
# Processing participant #1104
# Processing participant #1105
# Processing participant #1106
# Skipping participant #1106: empty epochs
# Processing participant #1107
# Skipping participant #1107: empty epochs
# Processing participant #1108
# Processing participant #1109
# Processing participant #1110
# Processing participant #1111
# Processing participant #1112
# Processing participant #1113
# Processing participant #1114
# Processing participant #1115
# Processing participant #1116
# Processing participant #1117
# Processing participant #1118
# Processing participant #1119
# Processing participant #1120
# Skipping participant #1120: empty epochs
# Processing participant #1121
# Skipping participant #1121: empty epochs
# Processing participant #1122
# Processing participant #1123
# Processing participant #1124
# Processing participant #1125
# Processing participant #1126
# Processing participant #1127
# Processing participant #1128
# Processing participant #1129
# Processing participant #1130
# Processing participant #1131
# Processing participant #1132
# Processing participant #1133
# Processing participant #1134
# Skipping participant #1134: empty epochs
# Processing participant #1135
# Skipping participant #1135: empty epochs
# Processing participant #1136
# Processing participant #1137
# Processing participant #1138
# Processing participant #1139
# Processing participant #1140
# Processing participant #1141
# Processing participant #1142
# Processing participant #1143
# Processing participant #1144
# Processing participant #1145
# Processing participant #1146
# Processing participant #1147
# Processing participant #1148
# Skipping participant #1148: empty epochs
# Processing participant #1149
# Skipping participant #1149: empty epochs
# Processing participant #1150
# Processing participant #1151
# Processing participant #1152
# Processing participant #1153
# Processing participant #1154
# Processing participant #1155
# Processing participant #1156
# Processing participant #1157
# Processing participant #1158
# Processing participant #1159
# Processing participant #1160
# Processing participant #1161
# Processing participant #1162
# Skipping participant #1162: empty epochs
# Processing participant #1163
# Skipping participant #1163: empty epochs
# Processing participant #1164
# Processing participant #1165
# Processing participant #1166
# Processing participant #1167
# Processing participant #1168
# Processing participant #1169
# Processing participant #1170
# Processing participant #1171
# Processing participant #1172
# Processing participant #1173
# Processing participant #1174
# Processing participant #1175
# Processing participant #1176
# Skipping participant #1176: empty epochs
# Processing participant #1177
# Skipping participant #1177: empty epochs
# Processing participant #1178
# Processing participant #1179
# Processing participant #1180
# Processing participant #1181
# Processing participant #1182
# Processing participant #1183
# Processing participant #1184
# Processing participant #1185
# Processing participant #1186
# Processing participant #1187
# Processing participant #1188
# Processing participant #1189
# Processing participant #1190
# Skipping participant #1190: empty epochs
# Processing participant #1191
# Skipping participant #1191: empty epochs
# Processing participant #1192
# Processing participant #1193
# Processing participant #1194
# Processing participant #1195
# Processing participant #1196
# Processing participant #1197
# Processing participant #1198
# Processing participant #1199
# Processing participant #1200
# Processing participant #1201
# Processing participant #1202
# Processing participant #1203
# Processing participant #1204
# Skipping participant #1204: empty epochs
# Processing participant #1205
# Skipping participant #1205: empty epochs
# Processing participant #1206
# Processing participant #1207
# Processing participant #1208
# Processing participant #1209
# Processing participant #1210
# Processing participant #1211
# Processing participant #1212
# Processing participant #1213
# Processing participant #1214
# Processing participant #1215
# Processing participant #1216
# Processing participant #1217
# Processing participant #1218
# Skipping participant #1218: empty epochs
# Processing participant #1219
# Skipping participant #1219: empty epochs
# Processing participant #1220
# Processing participant #1221
# Processing participant #1222
# Processing participant #1223
# Processing participant #1224
# Processing participant #1225
# Processing participant #1226
# Processing participant #1227
# Processing participant #1228
# Processing participant #1229
# Processing participant #1230
# Processing participant #1231
# Processing participant #1232
# Skipping participant #1232: empty epochs
# Processing participant #1233
# Skipping participant #1233: empty epochs
# Processing participant #1234
# Processing participant #1235
# Processing participant #1236
# Processing participant #1237
# Processing participant #1238
# Processing participant #1239
# Processing participant #1240
# Processing participant #1241
# Processing participant #1242
# Processing participant #1243
# Processing participant #1244
# Processing participant #1245
# Processing participant #1246
# Skipping participant #1246: empty epochs
# Processing participant #1247
# Skipping participant #1247: empty epochs
# Processing participant #1248
# Processing participant #1249
# Processing participant #1250
# Processing participant #1251
# Processing participant #1252
# Processing participant #1253
# Processing participant #1254
# Processing participant #1255
# Processing participant #1256
# Processing participant #1257
# Processing participant #1258
# Processing participant #1259
# Processing participant #1260
# Skipping participant #1260: empty epochs
# Processing participant #1261
# Skipping participant #1261: empty epochs
# Processing participant #1262
# Processing participant #1263
# Processing participant #1264
# Processing participant #1265
# Processing participant #1266
# Processing participant #1267
# Processing participant #1268
# Processing participant #1269
# Processing participant #1270
# Processing participant #1271
# Processing participant #1272
# Processing participant #1273
# Processing participant #1274
# Skipping participant #1274: empty epochs
# Processing participant #1275
# Skipping participant #1275: empty epochs
# Processing participant #1276
# Processing participant #1277
# Processing participant #1278
# Processing participant #1279
# Processing participant #1280
# Processing participant #1281
# Processing participant #1282
# Processing participant #1283
# Processing participant #1284
# Processing participant #1285
# Processing participant #1286
# Processing participant #1287
# Processing participant #1288
# Skipping participant #1288: empty epochs
# Processing participant #1289
# Skipping participant #1289: empty epochs
# Processing participant #1290
# Processing participant #1291
# Processing participant #1292
# Processing participant #1293
# Processing participant #1294
# Processing participant #1295
# Processing participant #1296
# Processing participant #1297
# Processing participant #1298
# Processing participant #1299
# Processing participant #1300
# Processing participant #1301
# Processing participant #1302
# Skipping participant #1302: empty epochs
# Processing participant #1303
# Skipping participant #1303: empty epochs
# Processing participant #1304
# Processing participant #1305
# Processing participant #1306
# Processing participant #1307
# Processing participant #1308
# Processing participant #1309
# Processing participant #1310
# Processing participant #1311
# Processing participant #1312
# Processing participant #1313
# Processing participant #1314
# Processing participant #1315
# Processing participant #1316
# Skipping participant #1316: empty epochs
# Processing participant #1317
# Skipping participant #1317: empty epochs
# Processing participant #1318
# Processing participant #1319
# Processing participant #1320
# Processing participant #1321
# Processing participant #1322
# Processing participant #1323
# Processing participant #1324
# Processing participant #1325
# Processing participant #1326
# Processing participant #1327
# Processing participant #1328
# Processing participant #1329
# Processing participant #1330
# Skipping participant #1330: empty epochs
# Processing participant #1331
# Skipping participant #1331: empty epochs
# Processing participant #1332
# Processing participant #1333
# Processing participant #1334
# Processing participant #1335
# Processing participant #1336
# Processing participant #1337
# Processing participant #1338
# Processing participant #1339
# Processing participant #1340
# Processing participant #1341
# Processing participant #1342
# Processing participant #1343
# Processing participant #1344
# Skipping participant #1344: empty epochs
# Processing participant #1345
# Skipping participant #1345: empty epochs
# Processing participant #1346
# Processing participant #1347
# Processing participant #1348
# Processing participant #1349
# Processing participant #1350
# Processing participant #1351
# Processing participant #1352
# Processing participant #1353
# Processing participant #1354
# Processing participant #1355
# Processing participant #1356
# Processing participant #1357
# Processing participant #1358
# Skipping participant #1358: empty epochs
# Processing participant #1359
# Skipping participant #1359: empty epochs
# Processing participant #1360
# Processing participant #1361
# Processing participant #1362
# Processing participant #1363
# Processing participant #1364
# Processing participant #1365
# Processing participant #1366
# Processing participant #1367
# Processing participant #1368
# Processing participant #1369
# Processing participant #1370
# Processing participant #1371
# Processing participant #1372
# Skipping participant #1372: empty epochs
# Processing participant #1373
# Skipping participant #1373: empty epochs
# Processing participant #1374
# Processing participant #1375
# Processing participant #1376
# Processing participant #1377
# Processing participant #1378
# Processing participant #1379
# Processing participant #1380
# Processing participant #1381
# Processing participant #1382
# Processing participant #1383
# Processing participant #1384
# Processing participant #1385
# Processing participant #1386
# Skipping participant #1386: empty epochs
# Processing participant #1387
# Skipping participant #1387: empty epochs
# Processing participant #1388
# Processing participant #1389
# Processing participant #1390
# Processing participant #1391
# Processing participant #1392
# Processing participant #1393
# Processing participant #1394
# Processing participant #1395
# Processing participant #1396
# Processing participant #1397
# Processing participant #1398
# Processing participant #1399
# Processing participant #1400
# Skipping participant #1400: empty epochs
# Processing participant #1401
# Skipping participant #1401: empty epochs
# Processing participant #1402
# Processing participant #1403
# Processing participant #1404
# Processing participant #1405
# Processing participant #1406
# Processing participant #1407
# Processing participant #1408
# Processing participant #1409
# Processing participant #1410
# Processing participant #1411
# Processing participant #1412
# Processing participant #1413
# Processing participant #1414
# Skipping participant #1414: empty epochs
# Processing participant #1415
# Skipping participant #1415: empty epochs
# Processing participant #1416
# Processing participant #1417
# Processing participant #1418
# Processing participant #1419
# Processing participant #1420
# Processing participant #1421
# Processing participant #1422
# Processing participant #1423
# Processing participant #1424
# Processing participant #1425
# Processing participant #1426
# Processing participant #1427
# Processing participant #1428
# Skipping participant #1428: empty epochs
# Processing participant #1429
# Skipping participant #1429: empty epochs
# Processing participant #1430
# Processing participant #1431
# Processing participant #1432
# Processing participant #1433
# Processing participant #1434
# Processing participant #1435
# Processing participant #1436
# Processing participant #1437
# Processing participant #1438
# Processing participant #1439
# Processing participant #1440
# Processing participant #1441
# Processing participant #1442
# Skipping participant #1442: empty epochs
# Processing participant #1443
# Skipping participant #1443: empty epochs
# Processing participant #1444
# Processing participant #1445
# Processing participant #1446
# Processing participant #1447
# Processing participant #1448
# Processing participant #1449
# Processing participant #1450
# Processing participant #1451
# Processing participant #1452
# Processing participant #1453
# Processing participant #1454
# Processing participant #1455
# Processing participant #1456
# Skipping participant #1456: empty epochs
# Processing participant #1457
# Skipping participant #1457: empty epochs
# Processing participant #1458
# Processing participant #1459
# Processing participant #1460
# Processing participant #1461
# Processing participant #1462
# Processing participant #1463
# Processing participant #1464
# Processing participant #1465
# Processing participant #1466
# Processing participant #1467
# Processing participant #1468
# Processing participant #1469
# Processing participant #1470
# Skipping participant #1470: empty epochs
# Processing participant #1471
# Skipping participant #1471: empty epochs
# Processing participant #1472
# Processing participant #1473
# Processing participant #1474
# Processing participant #1475
# Processing participant #1476
# Processing participant #1477
# Processing participant #1478
# Processing participant #1479
# Processing participant #1480
# Processing participant #1481
# Processing participant #1482
# Processing participant #1483
# Processing participant #1484
# Skipping participant #1484: empty epochs
# Processing participant #1485
# Skipping participant #1485: empty epochs
# Processing participant #1486
# Processing participant #1487
# Processing participant #1488
# Processing participant #1489
# Processing participant #1490
# Processing participant #1491
# Processing participant #1492
# Processing participant #1493
# Processing participant #1494
# Processing participant #1495
# Processing participant #1496
# Processing participant #1497
# Processing participant #1498
# Skipping participant #1498: empty epochs
# Processing participant #1499
# Skipping participant #1499: empty epochs
# Processing participant #1500
# Processing participant #1501
# Processing participant #1502
# Processing participant #1503
# Processing participant #1504
# Processing participant #1505
# Processing participant #1506
# Processing participant #1507
# Processing participant #1508
# Processing participant #1509
# Processing participant #1510
# Processing participant #1511
# Processing participant #1512
# Skipping participant #1512: empty epochs
# Processing participant #1513
# Skipping participant #1513: empty epochs
# Processing participant #1514
# Processing participant #1515
# Processing participant #1516
# Processing participant #1517
# Processing participant #1518
# Processing participant #1519
# Processing participant #1520
# Processing participant #1521
# Processing participant #1522
# Processing participant #1523
# Processing participant #1524
# Processing participant #1525
# Aligning all epochs to 91 time samples
# Final shapes:
# X: (38041, 64, 91)
# y: (38041,)
# groups: (38041,)

# %%
Y_CAT_MAPPING = {"rest" : 0,
                "both_feet" : 1, 
                "both_fist" : 2, 
                "left_fist" : 3, 
                "right_fist" : 4}

for key, value in Y_CAT_MAPPING.items():
        y[y == key] = value

# %%
X = X[(y != 0)] # Excluding label "rest" instances
y = y[(y != 0)]

# %% [markdown]
# # Building Model Architecture - Using Braindecode

# %%
# -----------------------------
# 1. Device configuration
# -----------------------------
def get_device():
    if torch.backends.mps.is_available():
        device = torch.device("mps")
        print("✅ Using Apple MPS device.")
    elif torch.cuda.is_available():
        device = torch.device("cuda")
        print("✅ Using CUDA device.")
    else:
        device = torch.device("cpu")
        print("⚠️ Using CPU.")
    return device


# -----------------------------
# 2. Data preprocessing
# -----------------------------
def prepare_data(X, y, test_size=0.2, val_size=0.1):
    le = LabelEncoder()
    y_encoded = le.fit_transform(y)

    X_tensor = torch.tensor(X, dtype=torch.float32)
    y_tensor = torch.tensor(y_encoded, dtype=torch.long)

    # Split train/test first
    X_train, X_temp, y_train, y_temp = train_test_split(
        X_tensor, y_tensor, test_size=test_size, random_state=42, stratify=y_encoded
    )

    # Split remaining into validation and test
    val_ratio = val_size / (1 - test_size)
    X_valid, X_test, y_valid, y_test = train_test_split(
        X_temp, y_temp, test_size=1 - val_ratio, random_state=42, stratify=y_temp
    )

    train_ds = TensorDataset(X_train, y_train)
    valid_ds = TensorDataset(X_valid, y_valid)
    test_ds = TensorDataset(X_test, y_test)

    print(f"Train set: {len(train_ds)}, Valid set: {len(valid_ds)}, Test set: {len(test_ds)}")
    return train_ds, valid_ds, test_ds, len(le.classes_)


# -----------------------------
# 3. Model setup
# -----------------------------
def create_model(n_chans, n_outputs, input_window_samples, sfreq, device):
    model = EEGNetv1(
        n_chans=n_chans,
        n_outputs= n_outputs,
        #sfreq=sfreq,
        n_times=input_window_samples,
        final_conv_length= "auto"
    )
    model.to(device)
    return model


# -----------------------------
# 4. Training setup
# -----------------------------
def train_model(model, train_ds, valid_ds, num_classes, device, n_epochs=10, batch_size=16):
    lr = 0.0625 * 0.01
    weight_decay = 0

    clf = EEGClassifier(
        model,
        criterion=nn.CrossEntropyLoss(),
        optimizer=torch.optim.AdamW,
        optimizer__lr=lr,
        optimizer__weight_decay=weight_decay,
        batch_size=batch_size,
        train_split=None,  # We'll pass valid_ds manually
        callbacks=[
            "accuracy",
            ("lr_scheduler", LRScheduler("CosineAnnealingLR", T_max=n_epochs - 1)),
        ],
        device=device,
        classes=list(range(num_classes)),
        max_epochs=n_epochs,
    )

    # Train using both train and valid sets
    print("🚀 Training started...")
    clf.fit(train_ds, y=None)
    print("✅ Training completed.")

    return clf


# -----------------------------
# 5. Evaluation
# -----------------------------
def evaluate_model(clf, test_ds):
    test_loader = DataLoader(test_ds, batch_size=16, shuffle=False)
    y_true, y_pred = [], []

    with torch.no_grad():
        for X_batch, y_batch in test_loader:
            preds = clf.predict(X_batch)
            y_true.extend(y_batch.numpy())
            y_pred.extend(preds)

    acc = (torch.tensor(y_true) == torch.tensor(y_pred)).float().mean().item()
    print(f"🧠 Test Accuracy: {acc:.4f}")
    return acc, y_true, y_pred



device = get_device()

train_ds, valid_ds, test_ds, num_classes = prepare_data(X, y)
model = create_model(n_chans=64, n_outputs=num_classes, input_window_samples=91, sfreq = 160, device=device)
clf = train_model(model, train_ds, valid_ds, num_classes, device, n_epochs=100, batch_size=32)
# Out:
# ✅ Using Apple MPS device.
# Train set: 15739, Valid set: 491, Test set: 3444
# 🚀 Training started...
# /Users/kavisanthoshkumar/Library/CloudStorage/OneDrive-IllinoisInstituteofTechnology/Tensorflow/tensorflow_env/lib/python3.9/site-packages/braindecode/models/base.py:180: UserWarning: LogSoftmax final layer will be removed! Please adjust your loss function accordingly (e.g. CrossEntropyLoss)!
#   warnings.warn("LogSoftmax final layer will be removed! " +
#   epoch    train_accuracy    train_loss      lr     dur
# -------  ----------------  ------------  ------  ------
#       1            0.2488        1.4680  0.0006  3.0025
#       2            0.2494        1.3974  0.0006  2.8836
#       3            0.2518        1.3872  0.0006  2.7058
#       4            0.2517        1.3486  0.0006  2.7006
#       5            0.2487        1.2785  0.0006  2.7971
#       6            0.2524        1.2568  0.0006  2.8983
#       7            0.2753        1.2357  0.0006  2.8584
#       8            0.2524        1.2196  0.0006  2.8340
#       9            0.2487        1.2105  0.0006  2.7941
#      10            0.2727        1.1991  0.0006  2.8447
#      11            0.2901        1.1908  0.0006  2.7853
#      12            0.2574        1.1863  0.0006  2.8217
#      13            0.3308        1.1824  0.0006  2.7851
#      14            0.2583        1.1724  0.0006  2.8271
#      15            0.2487        1.1735  0.0006  2.8588
#      16            0.3501        1.1694  0.0006  2.8467
#      17            0.2552        1.1656  0.0006  2.8247
#      18            0.2517        1.1665  0.0006  2.8229
#      19            0.2560        1.1605  0.0006  2.7929
#      20            0.2940        1.1584  0.0006  2.8095
#      21            0.2511        1.1567  0.0006  2.7875
#      22            0.2506        1.1529  0.0006  2.8500
#      23            0.2677        1.1539  0.0006  2.8709
#      24            0.2495        1.1563  0.0005  2.7835
#      25            0.2513        1.1536  0.0005  2.8773
#      26            0.2900        1.1470  0.0005  2.8219
#      27            0.2967        1.1485  0.0005  2.8575
#      28            0.3383        1.1473  0.0005  2.8390
#      29            0.2639        1.1483  0.0005  2.8422
#      30            0.2907        1.1435  0.0005  2.7845
#      31            0.2491        1.1422  0.0005  2.7069
#      32            0.2487        1.1353  0.0005  2.8215
#      33            0.2487        1.1407  0.0005  2.8311
#      34            0.2559        1.1380  0.0005  2.8494
#      35            0.2572        1.1365  0.0005  2.8275
#      36            0.2587        1.1393  0.0005  2.8193
#      37            0.2507        1.1341  0.0004  2.8202
#      38            0.2997        1.1341  0.0004  2.8518
#      39            0.3005        1.1296  0.0004  2.8251
#      40            0.2725        1.1360  0.0004  2.8017
#      41            0.2831        1.1258  0.0004  2.8517
#      42            0.2923        1.1296  0.0004  2.8053
#      43            0.2728        1.1295  0.0004  2.8317
#      44            0.2487        1.1260  0.0004  2.8292
#      45            0.3181        1.1251  0.0004  2.8691
#      46            0.2487        1.1245  0.0004  2.8689
#      47            0.3702        1.1279  0.0003  2.8061
#      48            0.3285        1.1253  0.0003  2.8445
#      49            0.2754        1.1170  0.0003  2.8114
#      50            0.2803        1.1208  0.0003  2.8221
#      51            0.2511        1.1218  0.0003  2.8322
#      52            0.2681        1.1254  0.0003  2.8309
#      53            0.3118        1.1191  0.0003  2.8022
#      54            0.2494        1.1193  0.0003  2.8514
#      55            0.2689        1.1184  0.0003  2.8381
#      56            0.2513        1.1174  0.0003  2.7441
#      57            0.2994        1.1159  0.0002  2.7375
#      58            0.2851        1.1188  0.0002  2.8446
#      59            0.3481        1.1138  0.0002  2.8315
#      60            0.3059        1.1135  0.0002  2.8291
#      61            0.2662        1.1151  0.0002  2.8595
#      62            0.2904        1.1132  0.0002  2.8333
#      63            0.4211        1.1094  0.0002  2.7803
#      64            0.2534        1.1151  0.0002  2.8411
#      65            0.3784        1.1141  0.0002  2.8464
#      66            0.2930        1.1170  0.0002  2.8246
#      67            0.2807        1.1059  0.0002  2.8103
#      68            0.3275        1.1130  0.0001  2.7967
#      69            0.3592        1.1087  0.0001  2.8272
#      70            0.3575        1.1085  0.0001  2.8198
#      71            0.3780        1.1092  0.0001  2.8228
#      72            0.3714        1.1105  0.0001  2.8564
#      73            0.3210        1.1122  0.0001  2.8298
#      74            0.3562        1.1080  0.0001  2.8059
#      75            0.3676        1.1034  0.0001  2.8521
#      76            0.3796        1.1096  0.0001  2.8394
#      77            0.4170        1.1121  0.0001  2.8548
#      78            0.4000        1.1066  0.0001  2.8564
#      79            0.4113        1.1082  0.0001  2.8552
#      80            0.4379        1.1049  0.0001  2.8273
#      81            0.4981        1.1097  0.0001  2.8462
#      82            0.4688        1.1114  0.0000  2.7947
#      83            0.4677        1.1155  0.0000  2.8606
#      84            0.4107        1.1077  0.0000  2.8526
#      85            0.4345        1.1072  0.0000  2.8075
#      86            0.5314        1.1053  0.0000  2.8368
#      87            0.4626        1.1029  0.0000  2.8216
#      88            0.5470        1.1108  0.0000  2.8378
#      89            0.5191        1.1056  0.0000  2.8197
#      90            0.5044        1.1055  0.0000  2.8297
#      91            0.5346        1.1062  0.0000  2.8393
#      92            0.5492        1.1106  0.0000  2.8540
#      93            0.5667        1.1046  0.0000  2.8183
#      94            0.5635        1.1009  0.0000  2.8287
#      95            0.5543        1.1106  0.0000  2.8253
#      96            0.5563        1.1048  0.0000  2.8869
#      97            0.5617        1.1064  0.0000  2.8504
#      98            0.5598        1.1023  0.0000  2.8343
#      99            0.5605        1.1001  0.0000  2.7997
#     100            0.5612        1.1035  0.0000  2.8106
# ✅ Training completed.

# %%
acc, y_true_train, y_pred = evaluate_model(clf, train_ds)
cm = confusion_matrix(y_true_train, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=list(range(num_classes)))
disp.plot() # will appear at the end of the output
print(classification_report(y_true_train, y_pred))
# Out:
# 🧠 Test Accuracy: 0.5612
#               precision    recall  f1-score   support
#
#            0       0.50      0.65      0.56      3939
#            1       0.53      0.43      0.48      3924
#            2       0.63      0.61      0.62      3961
#            3       0.62      0.55      0.58      3915
#
#     accuracy                           0.56     15739
#    macro avg       0.57      0.56      0.56     15739
# weighted avg       0.57      0.56      0.56     15739

# %%
acc, y_true, y_pred = evaluate_model(clf, test_ds)
cm = confusion_matrix(y_true, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=list(range(num_classes)))
disp.plot() # will appear at the end of the output
print(classification_report(y_true, y_pred))
# Out:
# 🧠 Test Accuracy: 0.5540
#               precision    recall  f1-score   support
#
#            0       0.48      0.64      0.55       862
#            1       0.52      0.43      0.47       859
#            2       0.61      0.58      0.60       866
#            3       0.63      0.56      0.59       857
#
#     accuracy                           0.55      3444
#    macro avg       0.56      0.55      0.55      3444
# weighted avg       0.56      0.55      0.55      3444
